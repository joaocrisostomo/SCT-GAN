# %%
from test_model import SmartContractAnalyzer, print_vulnerability_report
from inference import *

# PyTorch imports
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

# Model imports
from model import SmartContractTransformer

# Optional but useful imports
import numpy as np
from tqdm import tqdm  # for progress bars
import logging

from transformers import AutoTokenizer
import json
import os
import pandas as pd
from typing import Dict, List, Tuple, Any
import re
# Out:
# /home/m20180848/.conda/envs/pytorch_p310/lib/python3.10/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %% [raw]
# import importlib
# from inference import SmartContractAnalyzer
#
# importlib.reload(SmartContractAnalyzer)

# %% [markdown]
# # 1. Load Validation Dataset:

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

def parse_solidity_to_ast(code: str) -> Dict[str, Any]:
    """
    Parse Solidity code into a simplified AST structure
    """
    def extract_contract_info(code: str) -> Dict[str, Any]:
        # Extract contract name
        contract_match = re.search(r'contract\s+(\w+)', code)
        contract_name = contract_match.group(1) if contract_match else "Unknown"
        
        # Extract functions
        functions = []
        function_pattern = r'function\s+(\w+)\s*\(([^)]*)\)\s*(?:public|private|internal|external)?\s*(?:view|pure|payable)?\s*(?:returns\s*\(([^)]*)\))?\s*{'
        for match in re.finditer(function_pattern, code):
            func_name = match.group(1)
            params = match.group(2).split(',') if match.group(2) else []
            returns = match.group(3).split(',') if match.group(3) else []
            
            functions.append({
                'name': func_name,
                'parameters': [p.strip() for p in params],
                'returns': [r.strip() for r in returns]
            })
        
        # Extract state variables
        variables = []
        var_pattern = r'(?:uint|address|string|bool|mapping)\s+(?:\w+)\s+(\w+)'
        for match in re.finditer(var_pattern, code):
            variables.append(match.group(1))
        
        return {
            'type': 'Contract',
            'name': contract_name,
            'functions': functions,
            'variables': variables
        }
    
    try:
        # Clean the code
        code = re.sub(r'//.*?\n|/\*.*?\*/', '', code)  # Remove comments
        code = re.sub(r'\s+', ' ', code)  # Normalize whitespace
        
        # Parse the code
        ast = extract_contract_info(code)
        return ast
    except Exception as e:
        print(f"Error parsing code: {str(e)}")
        return None

def prepare_code2vec_input(ast: Dict[str, Any]) -> List[str]:
    """
    Convert AST to codeBert input format
    """
    paths = []
    
    def extract_paths(node: Dict[str, Any], current_path: List[str] = None):
        if current_path is None:
            current_path = []
            
        # Add current node to path
        if 'name' in node:
            current_path.append(node['name'])
            
        # Process functions
        if 'functions' in node:
            for func in node['functions']:
                func_path = current_path + [func['name']]
                paths.append(' '.join(func_path))
                
                # Add parameter paths
                for param in func['parameters']:
                    param_path = func_path + [param]
                    paths.append(' '.join(param_path))
                
                # Add return paths
                for ret in func['returns']:
                    ret_path = func_path + [ret]
                    paths.append(' '.join(ret_path))
        
        # Process variables
        if 'variables' in node:
            for var in node['variables']:
                var_path = current_path + [var]
                paths.append(' '.join(var_path))
    
    extract_paths(ast)
    return paths

class SmartContractVulnerabilityDataset(Dataset):
    def __init__(
        self,
        data_path: str,
        tokenizer: AutoTokenizer,
        max_length: int = 1024,
        split: str = "train",
        vulnerability_types: List[str] = None
    ):
        """
        Args:
            data_path: Path to the CSV file containing the dataset
            tokenizer: Tokenizer for encoding the source code
            max_length: Maximum sequence length
            split: "train" or "val" to specify which split to load
            vulnerability_types: List of vulnerability types to consider
        """
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.split = split
        self.vulnerability_types = vulnerability_types or [
            'ARTHM', 'DOS', 'LE', 'RENT', 'TimeM', 'TimeO', 'Tx-Origin', 'UE'
        ]
        
        # Load the dataset
        self.data = self._load_dataset(data_path)
        
    def _load_dataset(self, data_path: str) -> List[Dict]:
        """Load and preprocess the dataset from CSV"""
        dataset = []
        
        # Read the CSV file
        df = pd.read_csv(data_path)
        
        # Split into train/val if needed
        if self.split == "train":
            df = df.sample(frac=0.8, random_state=42)
        else:
            df = df.sample(frac=0.2, random_state=42)
        
        # Process each contract
        for _, row in df.iterrows():
            try:
                source_code = row['source_code']
                contract_name = row['contract_name']
                
                # Parse AST and get paths
                ast = parse_solidity_to_ast(source_code)
                ast_paths = prepare_code2vec_input(ast) if ast else []
                ast_path_text = ' '.join(ast_paths)
                
                # Split source code into lines
                lines = source_code.split('\n')
                
                # Create token-to-line mapping
                token_to_line = []
                current_line = 0
                
                # Tokenize each line separately to maintain mapping
                for line in lines:
                    line_tokens = self.tokenizer.encode(line, add_special_tokens=False)
                    token_to_line.extend([current_line] * len(line_tokens))
                    current_line += 1
                
                # Add special tokens
                token_to_line = [0] + token_to_line + [0]  # [CLS] and [SEP] tokens
                
                # Truncate if too long
                if len(token_to_line) > self.max_length:
                    token_to_line = token_to_line[:self.max_length]
                
                # Pad if too short
                if len(token_to_line) < self.max_length:
                    token_to_line.extend([0] * (self.max_length - len(token_to_line)))
                
                # Create multi-label line labels for each vulnerability type
                line_labels = self._create_multi_label_line_labels(source_code, row)
                
                # Create contract-level vulnerability labels
                contract_labels = self._create_contract_vulnerability_labels(row)
                
                # Tokenize the source code
                encoding = self.tokenizer(
                    source_code,
                    max_length=self.max_length,
                    padding='max_length',
                    truncation=True,
                    return_tensors='pt'
                )
                
                # Tokenize AST paths
                ast_encoding = self.tokenizer(
                    ast_path_text,
                    max_length=self.max_length,
                    padding='max_length',
                    truncation=True,
                    return_tensors='pt'
                )
                
                # Convert line labels to tensor and ensure consistent shape
                vuln_tensor = torch.zeros((len(self.vulnerability_types), self.max_length), dtype=torch.long)
                for i, labels in enumerate(line_labels):
                    if len(labels) > self.max_length:
                        labels = labels[:self.max_length]
                    vuln_tensor[i, :len(labels)] = torch.tensor(labels, dtype=torch.long)
                
                # Convert contract labels to tensor
                contract_vuln_tensor = torch.tensor(contract_labels, dtype=torch.long)
                
                # Convert token_to_line to tensor
                token_to_line_tensor = torch.tensor(token_to_line, dtype=torch.long)
                
                # Ensure attention masks are boolean
                attention_mask = encoding['attention_mask'].squeeze(0).bool()
                ast_attention_mask = ast_encoding['attention_mask'].squeeze(0).bool()
                
                # Ensure input_ids are the right length
                input_ids = encoding['input_ids'].squeeze(0)
                ast_input_ids = ast_encoding['input_ids'].squeeze(0)
                
                if len(input_ids) > self.max_length:
                    input_ids = input_ids[:self.max_length]
                if len(ast_input_ids) > self.max_length:
                    ast_input_ids = ast_input_ids[:self.max_length]
                
                # Pad if necessary
                if len(input_ids) < self.max_length:
                    input_ids = torch.nn.functional.pad(input_ids, (0, self.max_length - len(input_ids)))
                if len(ast_input_ids) < self.max_length:
                    ast_input_ids = torch.nn.functional.pad(ast_input_ids, (0, self.max_length - len(ast_input_ids)))
                
                dataset.append({
                    'input_ids': input_ids,
                    'attention_mask': attention_mask,
                    'ast_input_ids': ast_input_ids,
                    'ast_attention_mask': ast_attention_mask,
                    'vulnerable_lines': vuln_tensor,
                    'contract_vulnerabilities': contract_vuln_tensor,
                    'token_to_line': token_to_line_tensor,
                    'source_code': source_code,
                    'contract_name': contract_name
                })
            except Exception as e:
                print(f"Error processing contract {contract_name}: {str(e)}")
                continue
        
        return dataset
    
    def _create_contract_vulnerability_labels(self, row: pd.Series) -> List[int]:
        """Create contract-level vulnerability labels"""
        contract_labels = []
        for vuln_type in self.vulnerability_types:
            # Check if contract has this vulnerability type
            vuln_lines = row[f'{vuln_type}_lines']
            if isinstance(vuln_lines, str):
                try:
                    vuln_lines = eval(vuln_lines)
                except:
                    vuln_lines = [vuln_lines]
            
            # Contract is vulnerable if it has any vulnerable lines
            has_vulnerability = len(vuln_lines) > 0
            contract_labels.append(1 if has_vulnerability else 0)
        
        return contract_labels
    
    def _create_multi_label_line_labels(self, source_code: str, row: pd.Series) -> List[List[int]]:
        """Create multi-label line labels for each vulnerability type"""
        total_lines = len(source_code.split('\n'))
        line_labels = {vuln_type: [0] * total_lines for vuln_type in self.vulnerability_types}
        
        # Process each vulnerability type
        for vuln_type in self.vulnerability_types:
            vuln_lines = row[f'{vuln_type}_lines']
            if isinstance(vuln_lines, str):
                try:
                    vuln_lines = eval(vuln_lines)
                except:
                    vuln_lines = [vuln_lines]
            
            # Process each vulnerable line/snippet
            for line_or_snippet in vuln_lines:
                if isinstance(line_or_snippet, int):
                    # If it's a line number, mark that line
                    if 0 <= line_or_snippet < total_lines:
                        line_labels[vuln_type][line_or_snippet] = 1
                else:
                    # If it's a code snippet, find matching lines
                    source_lines = source_code.split('\n')
                    for i, line in enumerate(source_lines):
                        # Clean both the line and snippet for comparison
                        clean_line = re.sub(r'\s+', ' ', line.strip())
                        clean_snippet = re.sub(r'\s+', ' ', str(line_or_snippet).strip())
                        if clean_snippet in clean_line:
                            line_labels[vuln_type][i] = 1
        
        # Convert to list format
        return [line_labels[vuln_type] for vuln_type in self.vulnerability_types]
    
    def __len__(self) -> int:
        return len(self.data)
    
    def __getitem__(self, idx: int) -> Dict:
        return self.data[idx]

def custom_collate_fn(batch):
    """
    Custom collate function to handle variable length inputs
    """
    # Get the maximum length in this batch for each type of tensor
    max_input_len = max(item['input_ids'].size(0) for item in batch)
    
    # Pad all tensors to their respective maximum lengths
    padded_batch = {
        'input_ids': torch.stack([
            torch.nn.functional.pad(item['input_ids'], (0, max_input_len - item['input_ids'].size(0)))
            for item in batch
        ]),
        'attention_mask': torch.stack([
            torch.nn.functional.pad(item['attention_mask'], (0, max_input_len - item['attention_mask'].size(0)))
            for item in batch
        ]),
        'ast_input_ids': torch.stack([item['ast_input_ids'] for item in batch]),
        'ast_attention_mask': torch.stack([item['ast_attention_mask'] for item in batch]),
        'vulnerable_lines': torch.stack([item['vulnerable_lines'] for item in batch]),
        'contract_vulnerabilities': torch.stack([item['contract_vulnerabilities'] for item in batch]),
        'token_to_line': torch.stack([item['token_to_line'] for item in batch]),
        'source_code': [item['source_code'] for item in batch],
        'contract_name': [item['contract_name'] for item in batch]
    }
    
    return padded_batch

def create_dataloaders(
    data_path: str,
    tokenizer: AutoTokenizer,
    batch_size: int = 8,
    max_length: int = 1024,
    num_workers: int = 4,
    vulnerability_types: List[str] = None
) -> Tuple[torch.utils.data.DataLoader, torch.utils.data.DataLoader]:
    """
    Create train and validation dataloaders
    
    Args:
        data_path: Path to the CSV file containing the dataset
        tokenizer: Tokenizer for encoding the source code
        batch_size: Batch size for training
        max_length: Maximum sequence length
        num_workers: Number of workers for data loading
        vulnerability_types: List of vulnerability types to consider
    
    Returns:
        Tuple of (train_dataloader, val_dataloader)
    """
    # Create datasets
    train_dataset = SmartContractVulnerabilityDataset(
        data_path=data_path,
        tokenizer=tokenizer,
        max_length=max_length,
        split="train",
        vulnerability_types=vulnerability_types
    )
    
    val_dataset = SmartContractVulnerabilityDataset(
        data_path=data_path,
        tokenizer=tokenizer,
        max_length=max_length,
        split="val",
        vulnerability_types=vulnerability_types
    )
    
    # Create dataloaders with custom collate function
    train_dataloader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True,
        collate_fn=custom_collate_fn
    )
    
    val_dataloader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True,
        collate_fn=custom_collate_fn
    )
    
    return train_dataloader, val_dataloader

# %%
from transformers import AutoTokenizer

# Initialize tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/codebert-base")

# Create dataloaders
train_dataloader, val_dataloader = create_dataloaders(
    data_path="contract_sources_with_vulnerabilities_2048_token_size.csv",
    tokenizer=tokenizer,
    batch_size=8,
    max_length=1024,
    vulnerability_types=['ARTHM', 'DOS', 'LE', 'RENT', 'TimeM', 'TimeO', 'Tx-Origin', 'UE']
)
# Out:
# /home/m20180848/.conda/envs/pytorch_p310/lib/python3.10/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (1211 > 512). Running this sequence through the model will result in indexing errors

# %%
val_dataloader.dataset.max_length
# Out:
# 1024

# %% [markdown]
# # 2. Load Model and SmartContractAnalyzer

# %%
def calculate_precision(true_labels: np.ndarray, pred_labels: np.ndarray) -> float:
    """Calculate precision for vulnerability detection."""
    if np.sum(pred_labels) == 0:
        return 0.0
    return np.sum((true_labels == 1) & (pred_labels == 1)) / np.sum(pred_labels)

def calculate_recall(true_labels: np.ndarray, pred_labels: np.ndarray) -> float:
    """Calculate recall for vulnerability detection."""
    if np.sum(true_labels) == 0:
        return 0.0
    return np.sum((true_labels == 1) & (pred_labels == 1)) / np.sum(true_labels)

def calculate_f1_score(precision: float, recall: float) -> float:
    """Calculate F1 score."""
    if precision + recall == 0:
        return 0.0
    return 2 * (precision * recall) / (precision + recall)

def calculate_line_accuracy(true_line_vulns: np.ndarray, pred_line_vulns: Dict) -> float:
    """Calculate line-level accuracy (simplified)."""
    try:
        # Convert predicted line vulnerabilities to array format
        pred_array = np.zeros_like(true_line_vulns)
        for line_num, line_vulns in pred_line_vulns.items():
            if line_num < pred_array.shape[0]:
                for vuln_idx, is_vuln in enumerate(line_vulns.values()):
                    if vuln_idx < pred_array.shape[1]:
                        pred_array[line_num, vuln_idx] = 1 if is_vuln else 0
        
        return np.mean(pred_array == true_line_vulns)
    except:
        return 0.

def get_vulnerability_details(analyzer, true_vulns: np.ndarray, pred_vulns: np.ndarray, 
                            probabilities: List[float]) -> Dict[str, Any]:
    """Get detailed vulnerability analysis."""
    details = {}
    for i, vuln_type in enumerate(analyzer.vulnerability_types):
        details[vuln_type] = {
            'true_positive': bool(true_vulns[i] == 1 and pred_vulns[i] == 1),
            'false_positive': bool(true_vulns[i] == 0 and pred_vulns[i] == 1),
            'false_negative': bool(true_vulns[i] == 1 and pred_vulns[i] == 0),
            'true_negative': bool(true_vulns[i] == 0 and pred_vulns[i] == 0),
            'probability': probabilities[i],
            'true_label': int(true_vulns[i]),
            'predicted_label': int(pred_vulns[i])
        }
    return details

# %%
analyzer = SmartContractAnalyzer(
    model_path="checkpoints_v2_2048_output/best_model_epoch_126.pt",
    device="cuda" if torch.cuda.is_available() else "cpu"
)
# Out:
# /home/m20180848/.conda/envs/pytorch_p310/lib/python3.10/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/m20180848/.conda/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
batch_idx = 0
source_code = val_dataloader.dataset.data[0]['source_code']
contract_name = f'Contract_{batch_idx}'
true_contract_vulns = val_dataloader.dataset.data[0]['contract_vulnerabilities'].cpu().numpy()
true_line_vulns = val_dataloader.dataset.data[0]['vulnerable_lines'].cpu().numpy()

# %%
pred_results = analyzer.detect_vulnerabilities(source_code, threshold=0.5)
            
# Extract predictions
pred_contract_vulns = pred_results['contract_vulnerabilities']
pred_line_vulns = pred_results['line_vulnerabilities']
pred_contract_probs = pred_results['contract_probabilities'][0]

# Convert predictions to numpy arrays for comparison
pred_contract_array = np.array([
    1 if pred_contract_vulns[vuln_type] else 0 
    for vuln_type in analyzer.vulnerability_types
])

# Calculate metrics
contract_accuracy = np.mean(pred_contract_array == true_contract_vulns)
contract_precision = calculate_precision(true_contract_vulns, pred_contract_array)
contract_recall = calculate_recall(true_contract_vulns, pred_contract_array)
contract_f1 = calculate_f1_score(contract_precision, contract_recall)

# Line-level analysis (simplified)
line_accuracy = calculate_line_accuracy(true_line_vulns, pred_line_vulns)

generated_contracts = analyzer.generate_synthetic_contract(
    contract_template=source_code,
    num_contracts=1,
    temperature=0.9
)
generated_contract = generated_contracts[0] if generated_contracts else "Generation failed"
            

result = {
    'contract_name': contract_name,
    'batch_idx': batch_idx,
    'source_code': source_code,
    'true_contract_vulnerabilities': true_contract_vulns.tolist(),
    'predicted_contract_vulnerabilities': pred_contract_array.tolist(),
    'contract_probabilities': pred_contract_probs,
    'contract_accuracy': float(contract_accuracy),
    'contract_precision': float(contract_precision),
    'contract_recall': float(contract_recall),
    'contract_f1': float(contract_f1),
    'line_accuracy': float(line_accuracy),
    'vulnerability_details': get_vulnerability_details(analyzer, true_contract_vulns, pred_contract_array, pred_contract_probs),
    'generated_contract': generated_contracts
}
# Out:
# Contract vuln logits shape: torch.Size([1, 8])
# Line vuln logits shape: torch.Size([1, 1024, 8])
# Number of lines in contract: 90
# Contract predictions shape: (1, 8)
# Line predictions shape: (1, 1024, 8)
# Generating contract 1/1...
# Memory shape after encoding: torch.Size([1, 1024, 768])
# Starting generation with max_len: 1024
# Initial tgt shape: torch.Size([1, 1])
# Initial tgt: tensor([[0]], device='cuda:0')
# Step 0: Logits shape: torch.Size([1, 50265])
# Step 0: Logits range: [-21.5992, -2.5827]
# Step 0: Probs sum: 1.0000
# Step 0: Probs max: 1.0000
# Step 0: Next token: 4862
# Step 0: Current sequence length: 2
# Step 0: Last 5 tokens: [0, 4862]
# Step 1: Logits shape: torch.Size([1, 50265])
# Step 1: Logits range: [-17.6600, 1.5444]
# Step 1: Probs sum: 1.0000
# Step 1: Probs max: 1.0000
# Step 1: Next token: 1073
# Step 2: Logits shape: torch.Size([1, 50265])
# Step 2: Logits range: [-13.9757, 5.1368]
# Step 2: Probs sum: 1.0000
# Step 2: Probs max: 1.0000
# Step 2: Next token: 1916
# Step 3: Logits shape: torch.Size([1, 50265])
# Step 3: Logits range: [-21.5934, -3.0373]
# Step 3: Probs sum: 1.0000
# Step 3: Probs max: 1.0000
# Step 3: Next token: 2705
# Step 4: Logits shape: torch.Size([1, 50265])
# Step 4: Logits range: [-9.4495, 9.5017]
# Step 4: Probs sum: 1.0000
# Step 4: Probs max: 1.0000
# Step 4: Next token: 1571
# Step 5: Logits shape: torch.Size([1, 50265])
# Step 5: Logits range: [-21.0850, -0.9363]
# Step 5: Probs sum: 1.0000
# Step 5: Probs max: 1.0000
# Step 5: Next token: 37249
# Step 6: Logits shape: torch.Size([1, 50265])
# Step 6: Logits range: [-18.2406, 2.3969]
# Step 6: Probs sum: 1.0000
# Step 6: Probs max: 1.0000
# Step 6: Next token: 288
# Step 7: Logits shape: torch.Size([1, 50265])
# Step 7: Logits range: [-29.0771, -10.9481]
# Step 7: Probs sum: 1.0000
# Step 7: Probs max: 1.0000
# Step 7: Next token: 4
# Step 8: Logits shape: torch.Size([1, 50265])
# Step 8: Logits range: [-17.6480, 1.4826]
# Step 8: Probs sum: 1.0000
# Step 8: Probs max: 1.0000
# Step 8: Next token: 306
# Step 9: Logits shape: torch.Size([1, 50265])
# Step 9: Logits range: [-28.6932, -10.7313]
# Step 9: Probs sum: 1.0000
# Step 9: Probs max: 1.0000
# Step 9: Next token: 4
# Step 10: Logits shape: torch.Size([1, 50265])
# Step 10: Logits range: [-22.1820, 0.8813]
# Step 10: Probs sum: 1.0000
# Step 10: Probs max: 1.0000
# Step 10: Next token: 1646
# Step 10: Current sequence length: 12
# Step 10: Last 5 tokens: [288, 4, 306, 4, 1646]
# Step 11: Logits shape: torch.Size([1, 50265])
# Step 11: Logits range: [-27.2478, -9.7844]
# Step 11: Probs sum: 1.0000
# Step 11: Probs max: 1.0000
# Step 11: Next token: 131
# Step 12: Logits shape: torch.Size([1, 50265])
# Step 12: Logits range: [-31.0424, -15.0126]
# Step 12: Probs sum: 1.0000
# Step 12: Probs max: 1.0000
# Step 12: Next token: 50121
# Step 13: Logits shape: torch.Size([1, 50265])
# Step 13: Logits range: [-14.7539, 2.6874]
# Step 13: Probs sum: 1.0000
# Step 13: Probs max: 1.0000
# Step 13: Next token: 50118
# Step 14: Logits shape: torch.Size([1, 50265])
# Step 14: Logits range: [-32.1223, -16.2057]
# Step 14: Probs sum: 1.0000
# Step 14: Probs max: 1.0000
# Step 14: Next token: 50121
# Step 15: Logits shape: torch.Size([1, 50265])
# Step 15: Logits range: [-14.5121, 2.8945]
# Step 15: Probs sum: 1.0000
# Step 15: Probs max: 1.0000
# Step 15: Next token: 50118
# Step 16: Logits shape: torch.Size([1, 50265])
# Step 16: Logits range: [-27.5942, -8.0589]
# Step 16: Probs sum: 1.0000
# Step 16: Probs max: 1.0000
# Step 16: Next token: 31938
# Step 17: Logits shape: torch.Size([1, 50265])
# Step 17: Logits range: [-26.6142, -2.9918]
# Step 17: Probs sum: 1.0000
# Step 17: Probs max: 1.0000
# Step 17: Next token: 11056
# Step 18: Logits shape: torch.Size([1, 50265])
# Step 18: Logits range: [-26.6455, -6.8940]
# Step 18: Probs sum: 1.0000
# Step 18: Probs max: 1.0000
# Step 18: Next token: 45643
# Step 19: Logits shape: torch.Size([1, 50265])
# Step 19: Logits range: [-28.8943, -9.8506]
# Step 19: Probs sum: 1.0000
# Step 19: Probs max: 1.0000
# Step 19: Next token: 25522
# Step 20: Logits shape: torch.Size([1, 50265])
# Step 20: Logits range: [-31.0323, -14.9785]
# Step 20: Probs sum: 1.0000
# Step 20: Probs max: 1.0000
# Step 20: Next token: 50121
# Step 20: Current sequence length: 22
# Step 20: Last 5 tokens: [31938, 11056, 45643, 25522, 50121]
# Step 21: Logits shape: torch.Size([1, 50265])
# Step 21: Logits range: [-15.6918, 1.5887]
# Step 21: Probs sum: 1.0000
# Step 21: Probs max: 1.0000
# Step 21: Next token: 50118
# Step 22: Logits shape: torch.Size([1, 50265])
# Step 22: Logits range: [-36.1849, -21.7429]
# Step 22: Probs sum: 1.0000
# Step 22: Probs max: 1.0000
# Step 22: Next token: 1437
# Step 23: Logits shape: torch.Size([1, 50265])
# Step 23: Logits range: [-35.7126, -21.2502]
# Step 23: Probs sum: 1.0000
# Step 23: Probs max: 1.0000
# Step 23: Next token: 1437
# Step 24: Logits shape: torch.Size([1, 50265])
# Step 24: Logits range: [-34.8931, -20.3353]
# Step 24: Probs sum: 1.0000
# Step 24: Probs max: 1.0000
# Step 24: Next token: 1437
# Step 25: Logits shape: torch.Size([1, 50265])
# Step 25: Logits range: [-18.1179, 1.1328]
# Step 25: Probs sum: 1.0000
# Step 25: Probs max: 1.0000
# Step 25: Next token: 6755
# Step 26: Logits shape: torch.Size([1, 50265])
# Step 26: Logits range: [-25.9913, -6.9983]
# Step 26: Probs sum: 1.0000
# Step 26: Probs max: 1.0000
# Step 26: Next token: 285
# Step 27: Logits shape: torch.Size([1, 50265])
# Step 27: Logits range: [-22.6624, -1.8307]
# Step 27: Probs sum: 1.0000
# Step 27: Probs max: 1.0000
# Step 27: Next token: 766
# Step 28: Logits shape: torch.Size([1, 50265])
# Step 28: Logits range: [-27.4570, -10.0109]
# Step 28: Probs sum: 1.0000
# Step 28: Probs max: 1.0000
# Step 28: Next token: 131
# Step 29: Logits shape: torch.Size([1, 50265])
# Step 29: Logits range: [-31.3622, -15.3560]
# Step 29: Probs sum: 1.0000
# Step 29: Probs max: 1.0000
# Step 29: Next token: 50121
# Step 30: Logits shape: torch.Size([1, 50265])
# Step 30: Logits range: [-14.7903, 2.5941]
# Step 30: Probs sum: 1.0000
# Step 30: Probs max: 1.0000
# Step 30: Next token: 50118
# Step 30: Current sequence length: 32
# Step 30: Last 5 tokens: [285, 766, 131, 50121, 50118]
# Step 31: Logits shape: torch.Size([1, 50265])
# Step 31: Logits range: [-36.1835, -21.6338]
# Step 31: Probs sum: 1.0000
# Step 31: Probs max: 1.0000
# Step 31: Next token: 1437
# Step 32: Logits shape: torch.Size([1, 50265])
# Step 32: Logits range: [-36.0255, -21.5326]
# Step 32: Probs sum: 1.0000
# Step 32: Probs max: 1.0000
# Step 32: Next token: 1437
# Step 33: Logits shape: torch.Size([1, 50265])
# Step 33: Logits range: [-35.3597, -20.7751]
# Step 33: Probs sum: 1.0000
# Step 33: Probs max: 1.0000
# Step 33: Next token: 1437
# Step 34: Logits shape: torch.Size([1, 50265])
# Step 34: Logits range: [-17.9030, 1.4911]
# Step 34: Probs sum: 1.0000
# Step 34: Probs max: 1.0000
# Step 34: Next token: 6755
# Step 35: Logits shape: torch.Size([1, 50265])
# Step 35: Logits range: [-26.4999, -7.5357]
# Step 35: Probs sum: 1.0000
# Step 35: Probs max: 1.0000
# Step 35: Next token: 285
# Step 36: Logits shape: torch.Size([1, 50265])
# Step 36: Logits range: [-16.4476, 4.6884]
# Step 36: Probs sum: 1.0000
# Step 36: Probs max: 1.0000
# Step 36: Next token: 7648
# Step 37: Logits shape: torch.Size([1, 50265])
# Step 37: Logits range: [-27.3209, -9.9434]
# Step 37: Probs sum: 1.0000
# Step 37: Probs max: 1.0000
# Step 37: Next token: 131
# Step 38: Logits shape: torch.Size([1, 50265])
# Step 38: Logits range: [-31.0211, -14.9914]
# Step 38: Probs sum: 1.0000
# Step 38: Probs max: 1.0000
# Step 38: Next token: 50121
# Step 39: Logits shape: torch.Size([1, 50265])
# Step 39: Logits range: [-14.7634, 2.6209]
# Step 39: Probs sum: 1.0000
# Step 39: Probs max: 1.0000
# Step 39: Next token: 50118
# Step 40: Logits shape: torch.Size([1, 50265])
# Step 40: Logits range: [-36.1823, -21.7281]
# Step 40: Probs sum: 1.0000
# Step 40: Probs max: 1.0000
# Step 40: Next token: 1437
# Step 40: Current sequence length: 42
# Step 40: Last 5 tokens: [7648, 131, 50121, 50118, 1437]
# Step 41: Logits shape: torch.Size([1, 50265])
# Step 41: Logits range: [-36.2228, -21.8458]
# Step 41: Probs sum: 1.0000
# Step 41: Probs max: 1.0000
# Step 41: Next token: 1437
# Step 42: Logits shape: torch.Size([1, 50265])
# Step 42: Logits range: [-36.7611, -22.2889]
# Step 42: Probs sum: 1.0000
# Step 42: Probs max: 1.0000
# Step 42: Next token: 1437
# Step 43: Logits shape: torch.Size([1, 50265])
# Step 43: Logits range: [-26.9043, -8.4761]
# Step 43: Probs sum: 1.0000
# Step 43: Probs max: 1.0000
# Step 43: Next token: 49315
# Step 44: Logits shape: torch.Size([1, 50265])
# Step 44: Logits range: [-19.4210, 2.1812]
# Step 44: Probs sum: 1.0000
# Step 44: Probs max: 1.0000
# Step 44: Next token: 398
# Step 45: Logits shape: torch.Size([1, 50265])
# Step 45: Logits range: [-27.3664, -8.5141]
# Step 45: Probs sum: 1.0000
# Step 45: Probs max: 1.0000
# Step 45: Next token: 285
# Step 46: Logits shape: torch.Size([1, 50265])
# Step 46: Logits range: [-22.2184, -1.0816]
# Step 46: Probs sum: 1.0000
# Step 46: Probs max: 1.0000
# Step 46: Next token: 5044
# Step 47: Logits shape: torch.Size([1, 50265])
# Step 47: Logits range: [-14.3832, 7.4057]
# Step 47: Probs sum: 1.0000
# Step 47: Probs max: 1.0000
# Step 47: Next token: 757
# Step 48: Logits shape: torch.Size([1, 50265])
# Step 48: Logits range: [-14.2507, 7.5598]
# Step 48: Probs sum: 1.0000
# Step 48: Probs max: 1.0000
# Step 48: Next token: 1536
# Step 49: Logits shape: torch.Size([1, 50265])
# Step 49: Logits range: [-27.6548, -10.2927]
# Step 49: Probs sum: 1.0000
# Step 49: Probs max: 1.0000
# Step 49: Next token: 131
# Step 50: Logits shape: torch.Size([1, 50265])
# Step 50: Logits range: [-31.4974, -15.3419]
# Step 50: Probs sum: 1.0000
# Step 50: Probs max: 1.0000
# Step 50: Next token: 50121
# Step 50: Current sequence length: 52
# Step 50: Last 5 tokens: [5044, 757, 1536, 131, 50121]
# Step 51: Logits shape: torch.Size([1, 50265])
# Step 51: Logits range: [-15.0545, 2.3742]
# Step 51: Probs sum: 1.0000
# Step 51: Probs max: 1.0000
# Step 51: Next token: 50118
# Step 52: Logits shape: torch.Size([1, 50265])
# Step 52: Logits range: [-36.4360, -22.0122]
# Step 52: Probs sum: 1.0000
# Step 52: Probs max: 1.0000
# Step 52: Next token: 1437
# Step 53: Logits shape: torch.Size([1, 50265])
# Step 53: Logits range: [-36.4166, -22.0325]
# Step 53: Probs sum: 1.0000
# Step 53: Probs max: 1.0000
# Step 53: Next token: 1437
# Step 54: Logits shape: torch.Size([1, 50265])
# Step 54: Logits range: [-36.6396, -22.2254]
# Step 54: Probs sum: 1.0000
# Step 54: Probs max: 1.0000
# Step 54: Next token: 1437
# Step 55: Logits shape: torch.Size([1, 50265])
# Step 55: Logits range: [-26.5994, -8.0614]
# Step 55: Probs sum: 1.0000
# Step 55: Probs max: 1.0000
# Step 55: Next token: 49315
# Step 56: Logits shape: torch.Size([1, 50265])
# Step 56: Logits range: [-21.1885, -2.8938]
# Step 56: Probs sum: 1.0000
# Step 56: Probs max: 1.0000
# Step 56: Next token: 24554
# Step 57: Logits shape: torch.Size([1, 50265])
# Step 57: Logits range: [-26.5132, -7.5955]
# Step 57: Probs sum: 1.0000
# Step 57: Probs max: 1.0000
# Step 57: Next token: 285
# Step 58: Logits shape: torch.Size([1, 50265])
# Step 58: Logits range: [-24.9214, -5.5781]
# Step 58: Probs sum: 1.0000
# Step 58: Probs max: 1.0000
# Step 58: Next token: 746
# Step 59: Logits shape: torch.Size([1, 50265])
# Step 59: Logits range: [-21.5675, -0.9549]
# Step 59: Probs sum: 1.0000
# Step 59: Probs max: 1.0000
# Step 59: Next token: 33661
# Step 60: Logits shape: torch.Size([1, 50265])
# Step 60: Logits range: [-19.4344, 0.1304]
# Step 60: Probs sum: 1.0000
# Step 60: Probs max: 1.0000
# Step 60: Next token: 352
# Step 60: Current sequence length: 62
# Step 60: Last 5 tokens: [24554, 285, 746, 33661, 352]
# Step 61: Logits shape: torch.Size([1, 50265])
# Step 61: Logits range: [-28.1282, -10.7535]
# Step 61: Probs sum: 1.0000
# Step 61: Probs max: 1.0000
# Step 61: Next token: 131
# Step 62: Logits shape: torch.Size([1, 50265])
# Step 62: Logits range: [-31.1087, -15.0315]
# Step 62: Probs sum: 1.0000
# Step 62: Probs max: 1.0000
# Step 62: Next token: 50121
# Step 63: Logits shape: torch.Size([1, 50265])
# Step 63: Logits range: [-14.5547, 2.8224]
# Step 63: Probs sum: 1.0000
# Step 63: Probs max: 1.0000
# Step 63: Next token: 50118
# Step 64: Logits shape: torch.Size([1, 50265])
# Step 64: Logits range: [-31.3658, -15.3887]
# Step 64: Probs sum: 1.0000
# Step 64: Probs max: 1.0000
# Step 64: Next token: 50121
# Step 65: Logits shape: torch.Size([1, 50265])
# Step 65: Logits range: [-14.9569, 2.3595]
# Step 65: Probs sum: 1.0000
# Step 65: Probs max: 1.0000
# Step 65: Next token: 50118
# Step 66: Logits shape: torch.Size([1, 50265])
# Step 66: Logits range: [-36.1827, -21.7221]
# Step 66: Probs sum: 1.0000
# Step 66: Probs max: 1.0000
# Step 66: Next token: 1437
# Step 67: Logits shape: torch.Size([1, 50265])
# Step 67: Logits range: [-36.0859, -21.6988]
# Step 67: Probs sum: 1.0000
# Step 67: Probs max: 1.0000
# Step 67: Next token: 1437
# Step 68: Logits shape: torch.Size([1, 50265])
# Step 68: Logits range: [-35.5390, -21.0519]
# Step 68: Probs sum: 1.0000
# Step 68: Probs max: 1.0000
# Step 68: Next token: 1437
# Step 69: Logits shape: torch.Size([1, 50265])
# Step 69: Logits range: [-18.2034, 1.1599]
# Step 69: Probs sum: 1.0000
# Step 69: Probs max: 1.0000
# Step 69: Next token: 20410
# Step 70: Logits shape: torch.Size([1, 50265])
# Step 70: Logits range: [-30.5201, -11.8035]
# Step 70: Probs sum: 1.0000
# Step 70: Probs max: 1.0000
# Step 70: Next token: 36
# Step 70: Current sequence length: 72
# Step 70: Last 5 tokens: [1437, 1437, 1437, 20410, 36]
# Step 71: Logits shape: torch.Size([1, 50265])
# Step 71: Logits range: [-28.3708, -9.4116]
# Step 71: Probs sum: 1.0000
# Step 71: Probs max: 1.0000
# Step 71: Next token: 44547
# Step 72: Logits shape: torch.Size([1, 50265])
# Step 72: Logits range: [-16.8548, 4.6003]
# Step 72: Probs sum: 1.0000
# Step 72: Probs max: 1.0000
# Step 72: Next token: 46161
# Step 73: Logits shape: torch.Size([1, 50265])
# Step 73: Logits range: [-26.6477, -8.1952]
# Step 73: Probs sum: 1.0000
# Step 73: Probs max: 1.0000
# Step 73: Next token: 49315
# Step 74: Logits shape: torch.Size([1, 50265])
# Step 74: Logits range: [-23.8004, -5.4853]
# Step 74: Probs sum: 1.0000
# Step 74: Probs max: 1.0000
# Step 74: Next token: 24554
# Step 75: Logits shape: torch.Size([1, 50265])
# Step 75: Logits range: [-30.3134, -11.4788]
# Step 75: Probs sum: 1.0000
# Step 75: Probs max: 1.0000
# Step 75: Next token: 43
# Step 76: Logits shape: torch.Size([1, 50265])
# Step 76: Logits range: [-25.9306, -6.9910]
# Step 76: Probs sum: 1.0000
# Step 76: Probs max: 1.0000
# Step 76: Next token: 285
# Step 77: Logits shape: torch.Size([1, 50265])
# Step 77: Logits range: [-19.5245, -0.2643]
# Step 77: Probs sum: 1.0000
# Step 77: Probs max: 1.0000
# Step 77: Next token: 2394
# Step 78: Logits shape: torch.Size([1, 50265])
# Step 78: Logits range: [-18.5459, 0.4709]
# Step 78: Probs sum: 1.0000
# Step 78: Probs max: 1.0000
# Step 78: Next token: 10643
# Step 79: Logits shape: torch.Size([1, 50265])
# Step 79: Logits range: [-27.7403, -10.1172]
# Step 79: Probs sum: 1.0000
# Step 79: Probs max: 1.0000
# Step 79: Next token: 131
# Step 80: Logits shape: torch.Size([1, 50265])
# Step 80: Logits range: [-31.1269, -15.0512]
# Step 80: Probs sum: 1.0000
# Step 80: Probs max: 1.0000
# Step 80: Next token: 50121
# Step 80: Current sequence length: 82
# Step 80: Last 5 tokens: [285, 2394, 10643, 131, 50121]
# Step 81: Logits shape: torch.Size([1, 50265])
# Step 81: Logits range: [-14.6265, 2.7797]
# Step 81: Probs sum: 1.0000
# Step 81: Probs max: 1.0000
# Step 81: Next token: 50118
# Step 82: Logits shape: torch.Size([1, 50265])
# Step 82: Logits range: [-36.3089, -21.9581]
# Step 82: Probs sum: 1.0000
# Step 82: Probs max: 1.0000
# Step 82: Next token: 1437
# Step 83: Logits shape: torch.Size([1, 50265])
# Step 83: Logits range: [-36.2416, -21.9292]
# Step 83: Probs sum: 1.0000
# Step 83: Probs max: 1.0000
# Step 83: Next token: 1437
# Step 84: Logits shape: torch.Size([1, 50265])
# Step 84: Logits range: [-36.1075, -21.4990]
# Step 84: Probs sum: 1.0000
# Step 84: Probs max: 1.0000
# Step 84: Next token: 1437
# Step 85: Logits shape: torch.Size([1, 50265])
# Step 85: Logits range: [-18.6615, 0.7591]
# Step 85: Probs sum: 1.0000
# Step 85: Probs max: 1.0000
# Step 85: Next token: 20410
# Step 86: Logits shape: torch.Size([1, 50265])
# Step 86: Logits range: [-30.6972, -11.9150]
# Step 86: Probs sum: 1.0000
# Step 86: Probs max: 1.0000
# Step 86: Next token: 36
# Step 87: Logits shape: torch.Size([1, 50265])
# Step 87: Logits range: [-28.1498, -9.2940]
# Step 87: Probs sum: 1.0000
# Step 87: Probs max: 1.0000
# Step 87: Next token: 44547
# Step 88: Logits shape: torch.Size([1, 50265])
# Step 88: Logits range: [-17.0717, 4.2267]
# Step 88: Probs sum: 1.0000
# Step 88: Probs max: 1.0000
# Step 88: Next token: 46161
# Step 89: Logits shape: torch.Size([1, 50265])
# Step 89: Logits range: [-21.4815, -2.1522]
# Step 89: Probs sum: 1.0000
# Step 89: Probs max: 1.0000
# Step 89: Next token: 20410
# Step 90: Logits shape: torch.Size([1, 50265])
# Step 90: Logits range: [-31.5085, -12.8356]
# Step 90: Probs sum: 1.0000
# Step 90: Probs max: 1.0000
# Step 90: Next token: 36
# Step 90: Current sequence length: 92
# Step 90: Last 5 tokens: [36, 44547, 46161, 20410, 36]
# Step 91: Logits shape: torch.Size([1, 50265])
# Step 91: Logits range: [-28.7102, -9.7722]
# Step 91: Probs sum: 1.0000
# Step 91: Probs max: 1.0000
# Step 91: Next token: 44547
# Step 92: Logits shape: torch.Size([1, 50265])
# Step 92: Logits range: [-18.6064, 2.3273]
# Step 92: Probs sum: 1.0000
# Step 92: Probs max: 1.0000
# Step 92: Next token: 46161
# Step 93: Logits shape: torch.Size([1, 50265])
# Step 93: Logits range: [-26.9736, -8.4786]
# Step 93: Probs sum: 1.0000
# Step 93: Probs max: 1.0000
# Step 93: Next token: 49315
# Step 94: Logits shape: torch.Size([1, 50265])
# Step 94: Logits range: [-22.7504, -4.3918]
# Step 94: Probs sum: 1.0000
# Step 94: Probs max: 1.0000
# Step 94: Next token: 24554
# Step 95: Logits shape: torch.Size([1, 50265])
# Step 95: Logits range: [-14.5449, 6.2856]
# Step 95: Probs sum: 1.0000
# Step 95: Probs max: 1.0000
# Step 95: Next token: 35122
# Step 96: Logits shape: torch.Size([1, 50265])
# Step 96: Logits range: [-25.9740, -6.8035]
# Step 96: Probs sum: 1.0000
# Step 96: Probs max: 1.0000
# Step 96: Next token: 285
# Step 97: Logits shape: torch.Size([1, 50265])
# Step 97: Logits range: [-21.5183, -1.2839]
# Step 97: Probs sum: 1.0000
# Step 97: Probs max: 1.0000
# Step 97: Next token: 19488
# Step 98: Logits shape: torch.Size([1, 50265])
# Step 98: Logits range: [-28.1703, -10.5656]
# Step 98: Probs sum: 1.0000
# Step 98: Probs max: 1.0000
# Step 98: Next token: 131
# Step 99: Logits shape: torch.Size([1, 50265])
# Step 99: Logits range: [-31.1391, -15.0522]
# Step 99: Probs sum: 1.0000
# Step 99: Probs max: 1.0000
# Step 99: Next token: 50121
# Step 100: Logits shape: torch.Size([1, 50265])
# Step 100: Logits range: [-14.5546, 2.8393]
# Step 100: Probs sum: 1.0000
# Step 100: Probs max: 1.0000
# Step 100: Next token: 50118
# Step 100: Current sequence length: 102
# Step 100: Last 5 tokens: [285, 19488, 131, 50121, 50118]
# Step 101: Logits shape: torch.Size([1, 50265])
# Step 101: Logits range: [-31.3492, -15.4163]
# Step 101: Probs sum: 1.0000
# Step 101: Probs max: 1.0000
# Step 101: Next token: 50121
# Step 102: Logits shape: torch.Size([1, 50265])
# Step 102: Logits range: [-14.9189, 2.4279]
# Step 102: Probs sum: 1.0000
# Step 102: Probs max: 1.0000
# Step 102: Next token: 50118
# Step 103: Logits shape: torch.Size([1, 50265])
# Step 103: Logits range: [-35.9004, -21.4421]
# Step 103: Probs sum: 1.0000
# Step 103: Probs max: 1.0000
# Step 103: Next token: 1437
# Step 104: Logits shape: torch.Size([1, 50265])
# Step 104: Logits range: [-35.7637, -21.3079]
# Step 104: Probs sum: 1.0000
# Step 104: Probs max: 1.0000
# Step 104: Next token: 1437
# Step 105: Logits shape: torch.Size([1, 50265])
# Step 105: Logits range: [-35.2506, -20.5440]
# Step 105: Probs sum: 1.0000
# Step 105: Probs max: 1.0000
# Step 105: Next token: 1437
# Step 106: Logits shape: torch.Size([1, 50265])
# Step 106: Logits range: [-20.4733, 0.4213]
# Step 106: Probs sum: 1.0000
# Step 106: Probs max: 1.0000
# Step 106: Next token: 515
# Step 107: Logits shape: torch.Size([1, 50265])
# Step 107: Logits range: [-18.2582, 2.5593]
# Step 107: Probs sum: 1.0000
# Step 107: Probs max: 1.0000
# Step 107: Next token: 18853
# Step 108: Logits shape: torch.Size([1, 50265])
# Step 108: Logits range: [-31.3936, -13.1018]
# Step 108: Probs sum: 1.0000
# Step 108: Probs max: 1.0000
# Step 108: Next token: 1640
# Step 109: Logits shape: torch.Size([1, 50265])
# Step 109: Logits range: [-28.8022, -10.0971]
# Step 109: Probs sum: 1.0000
# Step 109: Probs max: 1.0000
# Step 109: Next token: 44547
# Step 110: Logits shape: torch.Size([1, 50265])
# Step 110: Logits range: [-22.9051, -1.7126]
# Step 110: Probs sum: 1.0000
# Step 110: Probs max: 1.0000
# Step 110: Next token: 43220
# Step 110: Current sequence length: 112
# Step 110: Last 5 tokens: [515, 18853, 1640, 44547, 43220]
# Step 111: Logits shape: torch.Size([1, 50265])
# Step 111: Logits range: [-23.4234, -2.6954]
# Step 111: Probs sum: 1.0000
# Step 111: Probs max: 1.0000
# Step 111: Next token: 31
# Step 112: Logits shape: torch.Size([1, 50265])
# Step 112: Logits range: [-31.4312, -13.6690]
# Step 112: Probs sum: 1.0000
# Step 112: Probs max: 1.0000
# Step 112: Next token: 6
# Step 113: Logits shape: torch.Size([1, 50265])
# Step 113: Logits range: [-19.7395, -1.1630]
# Step 113: Probs sum: 1.0000
# Step 113: Probs max: 1.0000
# Step 113: Next token: 1100
# Step 114: Logits shape: torch.Size([1, 50265])
# Step 114: Logits range: [-21.7024, -0.3991]
# Step 114: Probs sum: 1.0000
# Step 114: Probs max: 1.0000
# Step 114: Next token: 43220
# Step 115: Logits shape: torch.Size([1, 50265])
# Step 115: Logits range: [-23.5649, -4.4704]
# Step 115: Probs sum: 1.0000
# Step 115: Probs max: 1.0000
# Step 115: Next token: 7
# Step 116: Logits shape: torch.Size([1, 50265])
# Step 116: Logits range: [-32.0582, -14.4228]
# Step 116: Probs sum: 1.0000
# Step 116: Probs max: 1.0000
# Step 116: Next token: 6
# Step 117: Logits shape: torch.Size([1, 50265])
# Step 117: Logits range: [-26.2848, -7.7219]
# Step 117: Probs sum: 1.0000
# Step 117: Probs max: 1.0000
# Step 117: Next token: 49315
# Step 118: Logits shape: torch.Size([1, 50265])
# Step 118: Logits range: [-23.2119, -5.0633]
# Step 118: Probs sum: 1.0000
# Step 118: Probs max: 1.0000
# Step 118: Next token: 24554
# Step 119: Logits shape: torch.Size([1, 50265])
# Step 119: Logits range: [-27.2070, -6.1702]
# Step 119: Probs sum: 1.0000
# Step 119: Probs max: 1.0000
# Step 119: Next token: 923
# Step 120: Logits shape: torch.Size([1, 50265])
# Step 120: Logits range: [-26.9142, -8.4917]
# Step 120: Probs sum: 1.0000
# Step 120: Probs max: 1.0000
# Step 120: Next token: 4397
# Step 120: Current sequence length: 122
# Step 120: Last 5 tokens: [6, 49315, 24554, 923, 4397]
# Step 121: Logits shape: torch.Size([1, 50265])
# Step 121: Logits range: [-30.9928, -14.9494]
# Step 121: Probs sum: 1.0000
# Step 121: Probs max: 1.0000
# Step 121: Next token: 50121
# Step 122: Logits shape: torch.Size([1, 50265])
# Step 122: Logits range: [-14.6003, 2.7460]
# Step 122: Probs sum: 1.0000
# Step 122: Probs max: 1.0000
# Step 122: Next token: 50118
# Step 123: Logits shape: torch.Size([1, 50265])
# Step 123: Logits range: [-36.1689, -21.6882]
# Step 123: Probs sum: 1.0000
# Step 123: Probs max: 1.0000
# Step 123: Next token: 1437
# Step 124: Logits shape: torch.Size([1, 50265])
# Step 124: Logits range: [-36.1144, -21.6745]
# Step 124: Probs sum: 1.0000
# Step 124: Probs max: 1.0000
# Step 124: Next token: 1437
# Step 125: Logits shape: torch.Size([1, 50265])
# Step 125: Logits range: [-35.5598, -20.8464]
# Step 125: Probs sum: 1.0000
# Step 125: Probs max: 1.0000
# Step 125: Next token: 1437
# Step 126: Logits shape: torch.Size([1, 50265])
# Step 126: Logits range: [-21.9889, -0.7350]
# Step 126: Probs sum: 1.0000
# Step 126: Probs max: 1.0000
# Step 126: Next token: 515
# Step 127: Logits shape: torch.Size([1, 50265])
# Step 127: Logits range: [-17.5854, 4.7696]
# Step 127: Probs sum: 1.0000
# Step 127: Probs max: 1.0000
# Step 127: Next token: 23236
# Step 128: Logits shape: torch.Size([1, 50265])
# Step 128: Logits range: [-13.0885, 7.5839]
# Step 128: Probs sum: 1.0000
# Step 128: Probs max: 1.0000
# Step 128: Next token: 6486
# Step 129: Logits shape: torch.Size([1, 50265])
# Step 129: Logits range: [-31.7861, -13.5646]
# Step 129: Probs sum: 1.0000
# Step 129: Probs max: 1.0000
# Step 129: Next token: 1640
# Step 130: Logits shape: torch.Size([1, 50265])
# Step 130: Logits range: [-28.6859, -9.9550]
# Step 130: Probs sum: 1.0000
# Step 130: Probs max: 1.0000
# Step 130: Next token: 44547
# Step 130: Current sequence length: 132
# Step 130: Last 5 tokens: [515, 23236, 6486, 1640, 44547]
# Step 131: Logits shape: torch.Size([1, 50265])
# Step 131: Logits range: [-21.4179, -0.4735]
# Step 131: Probs sum: 1.0000
# Step 131: Probs max: 1.0000
# Step 131: Next token: 43220
# Step 132: Logits shape: torch.Size([1, 50265])
# Step 132: Logits range: [-25.4296, -5.5736]
# Step 132: Probs sum: 1.0000
# Step 132: Probs max: 1.0000
# Step 132: Next token: 1945
# Step 133: Logits shape: torch.Size([1, 50265])
# Step 133: Logits range: [-31.6182, -13.9190]
# Step 133: Probs sum: 1.0000
# Step 133: Probs max: 1.0000
# Step 133: Next token: 6
# Step 134: Logits shape: torch.Size([1, 50265])
# Step 134: Logits range: [-20.1450, -1.4918]
# Step 134: Probs sum: 1.0000
# Step 134: Probs max: 1.0000
# Step 134: Next token: 1100
# Step 135: Logits shape: torch.Size([1, 50265])
# Step 135: Logits range: [-22.2156, -1.0082]
# Step 135: Probs sum: 1.0000
# Step 135: Probs max: 1.0000
# Step 135: Next token: 43220
# Step 136: Logits shape: torch.Size([1, 50265])
# Step 136: Logits range: [-22.9031, -0.8768]
# Step 136: Probs sum: 1.0000
# Step 136: Probs max: 1.0000
# Step 136: Next token: 2292
# Step 137: Logits shape: torch.Size([1, 50265])
# Step 137: Logits range: [-23.3652, -3.2078]
# Step 137: Probs sum: 1.0000
# Step 137: Probs max: 1.0000
# Step 137: Next token: 7232
# Step 138: Logits shape: torch.Size([1, 50265])
# Step 138: Logits range: [-31.5906, -13.8548]
# Step 138: Probs sum: 1.0000
# Step 138: Probs max: 1.0000
# Step 138: Next token: 6
# Step 139: Logits shape: torch.Size([1, 50265])
# Step 139: Logits range: [-25.7672, -7.3265]
# Step 139: Probs sum: 1.0000
# Step 139: Probs max: 1.0000
# Step 139: Next token: 49315
# Step 140: Logits shape: torch.Size([1, 50265])
# Step 140: Logits range: [-22.5526, -4.3842]
# Step 140: Probs sum: 1.0000
# Step 140: Probs max: 1.0000
# Step 140: Next token: 24554
# Step 140: Current sequence length: 142
# Step 140: Last 5 tokens: [2292, 7232, 6, 49315, 24554]
# Step 141: Logits shape: torch.Size([1, 50265])
# Step 141: Logits range: [-26.8721, -6.1944]
# Step 141: Probs sum: 1.0000
# Step 141: Probs max: 1.0000
# Step 141: Next token: 923
# Step 142: Logits shape: torch.Size([1, 50265])
# Step 142: Logits range: [-27.1619, -8.7529]
# Step 142: Probs sum: 1.0000
# Step 142: Probs max: 1.0000
# Step 142: Next token: 4397
# Step 143: Logits shape: torch.Size([1, 50265])
# Step 143: Logits range: [-30.8279, -14.8262]
# Step 143: Probs sum: 1.0000
# Step 143: Probs max: 1.0000
# Step 143: Next token: 50121
# Step 144: Logits shape: torch.Size([1, 50265])
# Step 144: Logits range: [-14.3493, 3.0500]
# Step 144: Probs sum: 1.0000
# Step 144: Probs max: 1.0000
# Step 144: Next token: 50118
# Step 145: Logits shape: torch.Size([1, 50265])
# Step 145: Logits range: [-31.3292, -15.3587]
# Step 145: Probs sum: 1.0000
# Step 145: Probs max: 1.0000
# Step 145: Next token: 50121
# Step 146: Logits shape: torch.Size([1, 50265])
# Step 146: Logits range: [-14.8154, 2.5513]
# Step 146: Probs sum: 1.0000
# Step 146: Probs max: 1.0000
# Step 146: Next token: 50118
# Step 147: Logits shape: torch.Size([1, 50265])
# Step 147: Logits range: [-36.3841, -21.8514]
# Step 147: Probs sum: 1.0000
# Step 147: Probs max: 1.0000
# Step 147: Next token: 1437
# Step 148: Logits shape: torch.Size([1, 50265])
# Step 148: Logits range: [-36.3298, -21.7744]
# Step 148: Probs sum: 1.0000
# Step 148: Probs max: 1.0000
# Step 148: Next token: 1437
# Step 149: Logits shape: torch.Size([1, 50265])
# Step 149: Logits range: [-35.7602, -21.1576]
# Step 149: Probs sum: 1.0000
# Step 149: Probs max: 1.0000
# Step 149: Next token: 1437
# Step 150: Logits shape: torch.Size([1, 50265])
# Step 150: Logits range: [-18.9375, -0.0443]
# Step 150: Probs sum: 1.0000
# Step 150: Probs max: 1.0000
# Step 150: Next token: 5043
# Step 150: Current sequence length: 152
# Step 150: Last 5 tokens: [50118, 1437, 1437, 1437, 5043]
# Step 151: Logits shape: torch.Size([1, 50265])
# Step 151: Logits range: [-30.8234, -12.6650]
# Step 151: Probs sum: 1.0000
# Step 151: Probs max: 1.0000
# Step 151: Next token: 18134
# Step 152: Logits shape: torch.Size([1, 50265])
# Step 152: Logits range: [-23.7994, -4.5156]
# Step 152: Probs sum: 1.0000
# Step 152: Probs max: 1.0000
# Step 152: Next token: 40095
# Step 153: Logits shape: torch.Size([1, 50265])
# Step 153: Logits range: [-31.5295, -13.3185]
# Step 153: Probs sum: 1.0000
# Step 153: Probs max: 1.0000
# Step 153: Next token: 1640
# Step 154: Logits shape: torch.Size([1, 50265])
# Step 154: Logits range: [-29.3207, -10.5930]
# Step 154: Probs sum: 1.0000
# Step 154: Probs max: 1.0000
# Step 154: Next token: 44547
# Step 155: Logits shape: torch.Size([1, 50265])
# Step 155: Logits range: [-28.9038, -10.5915]
# Step 155: Probs sum: 1.0000
# Step 155: Probs max: 1.0000
# Step 155: Next token: 18134
# Step 156: Logits shape: torch.Size([1, 50265])
# Step 156: Logits range: [-14.9670, 4.2125]
# Step 156: Probs sum: 1.0000
# Step 156: Probs max: 1.0000
# Step 156: Next token: 7761
# Step 157: Logits shape: torch.Size([1, 50265])
# Step 157: Logits range: [-31.5020, -13.7234]
# Step 157: Probs sum: 1.0000
# Step 157: Probs max: 1.0000
# Step 157: Next token: 6
# Step 158: Logits shape: torch.Size([1, 50265])
# Step 158: Logits range: [-20.4812, -2.0038]
# Step 158: Probs sum: 1.0000
# Step 158: Probs max: 1.0000
# Step 158: Next token: 1100
# Step 159: Logits shape: torch.Size([1, 50265])
# Step 159: Logits range: [-28.8386, -10.7233]
# Step 159: Probs sum: 1.0000
# Step 159: Probs max: 1.0000
# Step 159: Next token: 18134
# Step 160: Logits shape: torch.Size([1, 50265])
# Step 160: Logits range: [-21.9809, -2.4748]
# Step 160: Probs sum: 1.0000
# Step 160: Probs max: 1.0000
# Step 160: Next token: 560
# Step 160: Current sequence length: 162
# Step 160: Last 5 tokens: [7761, 6, 1100, 18134, 560]
# Step 161: Logits shape: torch.Size([1, 50265])
# Step 161: Logits range: [-31.8601, -14.1848]
# Step 161: Probs sum: 1.0000
# Step 161: Probs max: 1.0000
# Step 161: Next token: 6
# Step 162: Logits shape: torch.Size([1, 50265])
# Step 162: Logits range: [-25.5759, -7.0502]
# Step 162: Probs sum: 1.0000
# Step 162: Probs max: 1.0000
# Step 162: Next token: 49315
# Step 163: Logits shape: torch.Size([1, 50265])
# Step 163: Logits range: [-29.5311, -11.2422]
# Step 163: Probs sum: 1.0000
# Step 163: Probs max: 1.0000
# Step 163: Next token: 18134
# Step 164: Logits shape: torch.Size([1, 50265])
# Step 164: Logits range: [-19.5017, 0.6055]
# Step 164: Probs sum: 1.0000
# Step 164: Probs max: 1.0000
# Step 164: Next token: 19434
# Step 165: Logits shape: torch.Size([1, 50265])
# Step 165: Logits range: [-31.1707, -12.2549]
# Step 165: Probs sum: 1.0000
# Step 165: Probs max: 1.0000
# Step 165: Next token: 43
# Step 166: Logits shape: torch.Size([1, 50265])
# Step 166: Logits range: [-20.9989, -0.2096]
# Step 166: Probs sum: 1.0000
# Step 166: Probs max: 1.0000
# Step 166: Next token: 3425
# Step 167: Logits shape: torch.Size([1, 50265])
# Step 167: Logits range: [-27.2219, -7.9475]
# Step 167: Probs sum: 1.0000
# Step 167: Probs max: 1.0000
# Step 167: Next token: 25522
# Step 168: Logits shape: torch.Size([1, 50265])
# Step 168: Logits range: [-31.0005, -14.9630]
# Step 168: Probs sum: 1.0000
# Step 168: Probs max: 1.0000
# Step 168: Next token: 50121
# Step 169: Logits shape: torch.Size([1, 50265])
# Step 169: Logits range: [-15.0368, 2.2408]
# Step 169: Probs sum: 1.0000
# Step 169: Probs max: 1.0000
# Step 169: Next token: 50118
# Step 170: Logits shape: torch.Size([1, 50265])
# Step 170: Logits range: [-36.3690, -21.8721]
# Step 170: Probs sum: 1.0000
# Step 170: Probs max: 1.0000
# Step 170: Next token: 1437
# Step 170: Current sequence length: 172
# Step 170: Last 5 tokens: [3425, 25522, 50121, 50118, 1437]
# Step 171: Logits shape: torch.Size([1, 50265])
# Step 171: Logits range: [-36.3349, -21.8558]
# Step 171: Probs sum: 1.0000
# Step 171: Probs max: 1.0000
# Step 171: Next token: 1437
# Step 172: Logits shape: torch.Size([1, 50265])
# Step 172: Logits range: [-36.1144, -21.6743]
# Step 172: Probs sum: 1.0000
# Step 172: Probs max: 1.0000
# Step 172: Next token: 1437
# Step 173: Logits shape: torch.Size([1, 50265])
# Step 173: Logits range: [-36.0047, -21.6117]
# Step 173: Probs sum: 1.0000
# Step 173: Probs max: 1.0000
# Step 173: Next token: 1437
# Step 174: Logits shape: torch.Size([1, 50265])
# Step 174: Logits range: [-36.0944, -21.6909]
# Step 174: Probs sum: 1.0000
# Step 174: Probs max: 1.0000
# Step 174: Next token: 1437
# Step 175: Logits shape: torch.Size([1, 50265])
# Step 175: Logits range: [-35.8944, -21.4336]
# Step 175: Probs sum: 1.0000
# Step 175: Probs max: 1.0000
# Step 175: Next token: 1437
# Step 176: Logits shape: torch.Size([1, 50265])
# Step 176: Logits range: [-36.4818, -21.5515]
# Step 176: Probs sum: 1.0000
# Step 176: Probs max: 1.0000
# Step 176: Next token: 1437
# Step 177: Logits shape: torch.Size([1, 50265])
# Step 177: Logits range: [-26.5864, -7.3771]
# Step 177: Probs sum: 1.0000
# Step 177: Probs max: 1.0000
# Step 177: Adding noise to prevent repetition
# Step 177: Next token: 1541
# Step 178: Logits shape: torch.Size([1, 50265])
# Step 178: Logits range: [-25.9678, -6.1547]
# Step 178: Probs sum: 1.0000
# Step 178: Probs max: 1.0000
# Step 178: Next token: 49604
# Step 179: Logits shape: torch.Size([1, 50265])
# Step 179: Logits range: [-22.4519, -3.0906]
# Step 179: Probs sum: 1.0000
# Step 179: Probs max: 1.0000
# Step 179: Next token: 560
# Step 180: Logits shape: torch.Size([1, 50265])
# Step 180: Logits range: [-25.7717, -5.3690]
# Step 180: Probs sum: 1.0000
# Step 180: Probs max: 1.0000
# Step 180: Next token: 49333
# Step 180: Current sequence length: 182
# Step 180: Last 5 tokens: [1437, 1541, 49604, 560, 49333]
# Step 181: Logits shape: torch.Size([1, 50265])
# Step 181: Logits range: [-19.9480, 0.0742]
# Step 181: Probs sum: 1.0000
# Step 181: Probs max: 1.0000
# Step 181: Next token: 321
# Step 182: Logits shape: torch.Size([1, 50265])
# Step 182: Logits range: [-27.3264, -6.3682]
# Step 182: Probs sum: 1.0000
# Step 182: Probs max: 1.0000
# Step 182: Next token: 1178
# Step 183: Logits shape: torch.Size([1, 50265])
# Step 183: Logits range: [-19.7765, 1.3324]
# Step 183: Probs sum: 1.0000
# Step 183: Probs max: 1.0000
# Step 183: Next token: 288
# Step 184: Logits shape: torch.Size([1, 50265])
# Step 184: Logits range: [-27.4270, -9.1763]
# Step 184: Probs sum: 1.0000
# Step 184: Probs max: 1.0000
# Step 184: Next token: 4397
# Step 185: Logits shape: torch.Size([1, 50265])
# Step 185: Logits range: [-31.1793, -15.1884]
# Step 185: Probs sum: 1.0000
# Step 185: Probs max: 1.0000
# Step 185: Next token: 50121
# Step 186: Logits shape: torch.Size([1, 50265])
# Step 186: Logits range: [-14.6161, 2.7280]
# Step 186: Probs sum: 1.0000
# Step 186: Probs max: 1.0000
# Step 186: Next token: 50118
# Step 187: Logits shape: torch.Size([1, 50265])
# Step 187: Logits range: [-36.2650, -21.7280]
# Step 187: Probs sum: 1.0000
# Step 187: Probs max: 1.0000
# Step 187: Next token: 1437
# Step 188: Logits shape: torch.Size([1, 50265])
# Step 188: Logits range: [-36.3016, -21.7428]
# Step 188: Probs sum: 1.0000
# Step 188: Probs max: 1.0000
# Step 188: Next token: 1437
# Step 189: Logits shape: torch.Size([1, 50265])
# Step 189: Logits range: [-36.0834, -21.5398]
# Step 189: Probs sum: 1.0000
# Step 189: Probs max: 1.0000
# Step 189: Next token: 1437
# Step 190: Logits shape: torch.Size([1, 50265])
# Step 190: Logits range: [-35.7021, -21.2117]
# Step 190: Probs sum: 1.0000
# Step 190: Probs max: 1.0000
# Step 190: Next token: 1437
# Step 190: Current sequence length: 192
# Step 190: Last 5 tokens: [50118, 1437, 1437, 1437, 1437]
# Step 191: Logits shape: torch.Size([1, 50265])
# Step 191: Logits range: [-35.5605, -21.1233]
# Step 191: Probs sum: 1.0000
# Step 191: Probs max: 1.0000
# Step 191: Next token: 1437
# Step 192: Logits shape: torch.Size([1, 50265])
# Step 192: Logits range: [-35.5641, -21.1288]
# Step 192: Probs sum: 1.0000
# Step 192: Probs max: 1.0000
# Step 192: Next token: 1437
# Step 193: Logits shape: torch.Size([1, 50265])
# Step 193: Logits range: [-34.9782, -20.4970]
# Step 193: Probs sum: 1.0000
# Step 193: Probs max: 1.0000
# Step 193: Next token: 1437
# Step 194: Logits shape: torch.Size([1, 50265])
# Step 194: Logits range: [-25.6369, -6.1672]
# Step 194: Probs sum: 1.0000
# Step 194: Probs max: 1.0000
# Step 194: Adding noise to prevent repetition
# Step 194: Next token: 17885
# Step 195: Logits shape: torch.Size([1, 50265])
# Step 195: Logits range: [-30.6685, -12.1944]
# Step 195: Probs sum: 1.0000
# Step 195: Probs max: 1.0000
# Step 195: Next token: 2703
# Step 196: Logits shape: torch.Size([1, 50265])
# Step 196: Logits range: [-31.8130, -13.6720]
# Step 196: Probs sum: 1.0000
# Step 196: Probs max: 1.0000
# Step 196: Next token: 1640
# Step 197: Logits shape: torch.Size([1, 50265])
# Step 197: Logits range: [-28.0392, -7.2930]
# Step 197: Probs sum: 1.0000
# Step 197: Probs max: 1.0000
# Step 197: Next token: 30821
# Step 198: Logits shape: torch.Size([1, 50265])
# Step 198: Logits range: [-18.8732, -0.0388]
# Step 198: Probs sum: 1.0000
# Step 198: Probs max: 1.0000
# Step 198: Next token: 10643
# Step 199: Logits shape: torch.Size([1, 50265])
# Step 199: Logits range: [-20.4004, -1.6952]
# Step 199: Probs sum: 1.0000
# Step 199: Probs max: 1.0000
# Step 199: Next token: 49895
# Step 200: Logits shape: torch.Size([1, 50265])
# Step 200: Logits range: [-15.6243, 3.6406]
# Step 200: Probs sum: 1.0000
# Step 200: Probs max: 1.0000
# Step 200: Next token: 7761
# Step 200: Current sequence length: 202
# Step 200: Last 5 tokens: [1640, 30821, 10643, 49895, 7761]
# Step 201: Logits shape: torch.Size([1, 50265])
# Step 201: Logits range: [-30.7541, -11.0564]
# Step 201: Probs sum: 1.0000
# Step 201: Probs max: 1.0000
# Step 201: Next token: 742
# Step 202: Logits shape: torch.Size([1, 50265])
# Step 202: Logits range: [-22.2181, -2.7472]
# Step 202: Probs sum: 1.0000
# Step 202: Probs max: 1.0000
# Step 202: Next token: 49095
# Step 203: Logits shape: torch.Size([1, 50265])
# Step 203: Logits range: [-29.6013, -11.2430]
# Step 203: Probs sum: 1.0000
# Step 203: Probs max: 1.0000
# Step 203: Next token: 18134
# Step 204: Logits shape: torch.Size([1, 50265])
# Step 204: Logits range: [-19.6046, 0.7559]
# Step 204: Probs sum: 1.0000
# Step 204: Probs max: 1.0000
# Step 204: Next token: 19434
# Step 205: Logits shape: torch.Size([1, 50265])
# Step 205: Logits range: [-27.9850, -9.7254]
# Step 205: Probs sum: 1.0000
# Step 205: Probs max: 1.0000
# Step 205: Next token: 4397
# Step 206: Logits shape: torch.Size([1, 50265])
# Step 206: Logits range: [-31.5553, -15.5168]
# Step 206: Probs sum: 1.0000
# Step 206: Probs max: 1.0000
# Step 206: Next token: 50121
# Step 207: Logits shape: torch.Size([1, 50265])
# Step 207: Logits range: [-15.4572, 1.8756]
# Step 207: Probs sum: 1.0000
# Step 207: Probs max: 1.0000
# Step 207: Next token: 50118
# Step 208: Logits shape: torch.Size([1, 50265])
# Step 208: Logits range: [-36.1605, -21.5295]
# Step 208: Probs sum: 1.0000
# Step 208: Probs max: 1.0000
# Step 208: Next token: 1437
# Step 209: Logits shape: torch.Size([1, 50265])
# Step 209: Logits range: [-36.0920, -21.4367]
# Step 209: Probs sum: 1.0000
# Step 209: Probs max: 1.0000
# Step 209: Next token: 1437
# Step 210: Logits shape: torch.Size([1, 50265])
# Step 210: Logits range: [-35.9519, -21.3643]
# Step 210: Probs sum: 1.0000
# Step 210: Probs max: 1.0000
# Step 210: Next token: 1437
# Step 210: Current sequence length: 212
# Step 210: Last 5 tokens: [50121, 50118, 1437, 1437, 1437]
# Step 211: Logits shape: torch.Size([1, 50265])
# Step 211: Logits range: [-35.7311, -21.1803]
# Step 211: Probs sum: 1.0000
# Step 211: Probs max: 1.0000
# Step 211: Next token: 1437
# Step 212: Logits shape: torch.Size([1, 50265])
# Step 212: Logits range: [-35.7306, -21.2506]
# Step 212: Probs sum: 1.0000
# Step 212: Probs max: 1.0000
# Step 212: Next token: 1437
# Step 213: Logits shape: torch.Size([1, 50265])
# Step 213: Logits range: [-35.6984, -21.1694]
# Step 213: Probs sum: 1.0000
# Step 213: Probs max: 1.0000
# Step 213: Next token: 1437
# Step 214: Logits shape: torch.Size([1, 50265])
# Step 214: Logits range: [-26.3894, -7.2060]
# Step 214: Probs sum: 1.0000
# Step 214: Probs max: 1.0000
# Step 214: Next token: 2703
# Step 215: Logits shape: torch.Size([1, 50265])
# Step 215: Logits range: [-31.5398, -13.3438]
# Step 215: Probs sum: 1.0000
# Step 215: Probs max: 1.0000
# Step 215: Next token: 1640
# Step 216: Logits shape: torch.Size([1, 50265])
# Step 216: Logits range: [-27.0637, -6.5713]
# Step 216: Probs sum: 1.0000
# Step 216: Probs max: 1.0000
# Step 216: Next token: 30821
# Step 217: Logits shape: torch.Size([1, 50265])
# Step 217: Logits range: [-18.8688, 0.1054]
# Step 217: Probs sum: 1.0000
# Step 217: Probs max: 1.0000
# Step 217: Next token: 10643
# Step 218: Logits shape: torch.Size([1, 50265])
# Step 218: Logits range: [-19.7102, -0.8618]
# Step 218: Probs sum: 1.0000
# Step 218: Probs max: 1.0000
# Step 218: Next token: 49895
# Step 219: Logits shape: torch.Size([1, 50265])
# Step 219: Logits range: [-22.2615, -3.1062]
# Step 219: Probs sum: 1.0000
# Step 219: Probs max: 1.0000
# Step 219: Next token: 560
# Step 220: Logits shape: torch.Size([1, 50265])
# Step 220: Logits range: [-30.6568, -10.5749]
# Step 220: Probs sum: 1.0000
# Step 220: Probs max: 1.0000
# Step 220: Next token: 742
# Step 220: Current sequence length: 222
# Step 220: Last 5 tokens: [30821, 10643, 49895, 560, 742]
# Step 221: Logits shape: torch.Size([1, 50265])
# Step 221: Logits range: [-20.7054, 0.2098]
# Step 221: Probs sum: 1.0000
# Step 221: Probs max: 1.0000
# Step 221: Next token: 2055
# Step 222: Logits shape: torch.Size([1, 50265])
# Step 222: Logits range: [-30.6478, -12.2729]
# Step 222: Probs sum: 1.0000
# Step 222: Probs max: 1.0000
# Step 222: Next token: 18134
# Step 223: Logits shape: torch.Size([1, 50265])
# Step 223: Logits range: [-19.3133, 0.7792]
# Step 223: Probs sum: 1.0000
# Step 223: Probs max: 1.0000
# Step 223: Next token: 19434
# Step 224: Logits shape: torch.Size([1, 50265])
# Step 224: Logits range: [-27.8295, -7.6704]
# Step 224: Probs sum: 1.0000
# Step 224: Probs max: 1.0000
# Step 224: Next token: 8061
# Step 225: Logits shape: torch.Size([1, 50265])
# Step 225: Logits range: [-20.6653, -1.2241]
# Step 225: Probs sum: 1.0000
# Step 225: Probs max: 1.0000
# Step 225: Next token: 2394
# Step 226: Logits shape: torch.Size([1, 50265])
# Step 226: Logits range: [-19.7762, -0.9241]
# Step 226: Probs sum: 1.0000
# Step 226: Probs max: 1.0000
# Step 226: Next token: 10643
# Step 227: Logits shape: torch.Size([1, 50265])
# Step 227: Logits range: [-19.7820, -1.0137]
# Step 227: Probs sum: 1.0000
# Step 227: Probs max: 1.0000
# Step 227: Next token: 49895
# Step 228: Logits shape: torch.Size([1, 50265])
# Step 228: Logits range: [-22.1249, -2.6903]
# Step 228: Probs sum: 1.0000
# Step 228: Probs max: 1.0000
# Step 228: Next token: 560
# Step 229: Logits shape: torch.Size([1, 50265])
# Step 229: Logits range: [-22.6648, -0.4688]
# Step 229: Probs sum: 1.0000
# Step 229: Probs max: 1.0000
# Step 229: Next token: 48601
# Step 230: Logits shape: torch.Size([1, 50265])
# Step 230: Logits range: [-31.3387, -15.3079]
# Step 230: Probs sum: 1.0000
# Step 230: Probs max: 1.0000
# Step 230: Next token: 50121
# Step 230: Current sequence length: 232
# Step 230: Last 5 tokens: [10643, 49895, 560, 48601, 50121]
# Step 231: Logits shape: torch.Size([1, 50265])
# Step 231: Logits range: [-14.8638, 2.5388]
# Step 231: Probs sum: 1.0000
# Step 231: Probs max: 1.0000
# Step 231: Next token: 50118
# Step 232: Logits shape: torch.Size([1, 50265])
# Step 232: Logits range: [-36.3197, -21.9229]
# Step 232: Probs sum: 1.0000
# Step 232: Probs max: 1.0000
# Step 232: Next token: 1437
# Step 233: Logits shape: torch.Size([1, 50265])
# Step 233: Logits range: [-36.2667, -21.8120]
# Step 233: Probs sum: 1.0000
# Step 233: Probs max: 1.0000
# Step 233: Next token: 1437
# Step 234: Logits shape: torch.Size([1, 50265])
# Step 234: Logits range: [-36.1797, -21.6874]
# Step 234: Probs sum: 1.0000
# Step 234: Probs max: 1.0000
# Step 234: Next token: 1437
# Step 235: Logits shape: torch.Size([1, 50265])
# Step 235: Logits range: [-35.8922, -21.3725]
# Step 235: Probs sum: 1.0000
# Step 235: Probs max: 1.0000
# Step 235: Next token: 1437
# Step 236: Logits shape: torch.Size([1, 50265])
# Step 236: Logits range: [-35.8740, -21.3923]
# Step 236: Probs sum: 1.0000
# Step 236: Probs max: 1.0000
# Step 236: Next token: 1437
# Step 237: Logits shape: torch.Size([1, 50265])
# Step 237: Logits range: [-35.8512, -21.4497]
# Step 237: Probs sum: 1.0000
# Step 237: Probs max: 1.0000
# Step 237: Next token: 1437
# Step 238: Logits shape: torch.Size([1, 50265])
# Step 238: Logits range: [-37.2408, -22.4007]
# Step 238: Probs sum: 1.0000
# Step 238: Probs max: 1.0000
# Step 238: Next token: 1437
# Step 239: Logits shape: torch.Size([1, 50265])
# Step 239: Logits range: [-27.1267, -8.7284]
# Step 239: Probs sum: 1.0000
# Step 239: Probs max: 1.0000
# Step 239: Adding noise to prevent repetition
# Step 239: Next token: 10567
# Step 240: Logits shape: torch.Size([1, 50265])
# Step 240: Logits range: [-35.7458, -16.0837]
# Step 240: Probs sum: 1.0000
# Step 240: Probs max: 1.0000
# Step 240: Next token: 49315
# Step 240: Current sequence length: 242
# Step 240: Last 5 tokens: [1437, 1437, 1437, 10567, 49315]
# Step 241: Logits shape: torch.Size([1, 50265])
# Step 241: Logits range: [-27.6696, -6.0893]
# Step 241: Probs sum: 1.0000
# Step 241: Probs max: 1.0000
# Step 241: Next token: 986
# Step 242: Logits shape: torch.Size([1, 50265])
# Step 242: Logits range: [-32.4205, -9.2435]
# Step 242: Probs sum: 1.0000
# Step 242: Probs max: 1.0000
# Step 242: Next token: 35917
# Step 243: Logits shape: torch.Size([1, 50265])
# Step 243: Logits range: [-24.5187, -3.1833]
# Step 243: Probs sum: 1.0000
# Step 243: Probs max: 1.0000
# Step 243: Next token: 5332
# Step 244: Logits shape: torch.Size([1, 50265])
# Step 244: Logits range: [-36.2750, -18.0519]
# Step 244: Probs sum: 1.0000
# Step 244: Probs max: 1.0000
# Step 244: Next token: 5457
# Step 245: Logits shape: torch.Size([1, 50265])
# Step 245: Logits range: [-21.8352, -2.8088]
# Step 245: Probs sum: 1.0000
# Step 245: Probs max: 1.0000
# Step 245: Next token: 2394
# Step 246: Logits shape: torch.Size([1, 50265])
# Step 246: Logits range: [-18.6511, 0.3319]
# Step 246: Probs sum: 1.0000
# Step 246: Probs max: 1.0000
# Step 246: Next token: 10643
# Step 247: Logits shape: torch.Size([1, 50265])
# Step 247: Logits range: [-18.9923, -0.3343]
# Step 247: Probs sum: 1.0000
# Step 247: Probs max: 1.0000
# Step 247: Next token: 49895
# Step 248: Logits shape: torch.Size([1, 50265])
# Step 248: Logits range: [-15.7427, 3.4977]
# Step 248: Probs sum: 1.0000
# Step 248: Probs max: 1.0000
# Step 248: Next token: 7761
# Step 249: Logits shape: torch.Size([1, 50265])
# Step 249: Logits range: [-30.8125, -11.2585]
# Step 249: Probs sum: 1.0000
# Step 249: Probs max: 1.0000
# Step 249: Next token: 742
# Step 250: Logits shape: torch.Size([1, 50265])
# Step 250: Logits range: [-19.4164, 1.4156]
# Step 250: Probs sum: 1.0000
# Step 250: Probs max: 1.0000
# Step 250: Next token: 2055
# Step 250: Current sequence length: 252
# Step 250: Last 5 tokens: [10643, 49895, 7761, 742, 2055]
# Step 251: Logits shape: torch.Size([1, 50265])
# Step 251: Logits range: [-21.6245, -2.5634]
# Step 251: Probs sum: 1.0000
# Step 251: Probs max: 1.0000
# Step 251: Next token: 2394
# Step 252: Logits shape: torch.Size([1, 50265])
# Step 252: Logits range: [-18.1888, 0.6224]
# Step 252: Probs sum: 1.0000
# Step 252: Probs max: 1.0000
# Step 252: Next token: 10643
# Step 253: Logits shape: torch.Size([1, 50265])
# Step 253: Logits range: [-19.0702, -0.4661]
# Step 253: Probs sum: 1.0000
# Step 253: Probs max: 1.0000
# Step 253: Next token: 49895
# Step 254: Logits shape: torch.Size([1, 50265])
# Step 254: Logits range: [-22.1078, -2.7199]
# Step 254: Probs sum: 1.0000
# Step 254: Probs max: 1.0000
# Step 254: Next token: 560
# Step 255: Logits shape: torch.Size([1, 50265])
# Step 255: Logits range: [-20.4922, 2.3045]
# Step 255: Probs sum: 1.0000
# Step 255: Probs max: 1.0000
# Step 255: Next token: 44082
# Step 256: Logits shape: torch.Size([1, 50265])
# Step 256: Logits range: [-31.3424, -15.3263]
# Step 256: Probs sum: 1.0000
# Step 256: Probs max: 1.0000
# Step 256: Next token: 50121
# Step 257: Logits shape: torch.Size([1, 50265])
# Step 257: Logits range: [-15.1254, 2.2122]
# Step 257: Probs sum: 1.0000
# Step 257: Probs max: 1.0000
# Step 257: Next token: 50118
# Step 258: Logits shape: torch.Size([1, 50265])
# Step 258: Logits range: [-36.0098, -21.3910]
# Step 258: Probs sum: 1.0000
# Step 258: Probs max: 1.0000
# Step 258: Next token: 1437
# Step 259: Logits shape: torch.Size([1, 50265])
# Step 259: Logits range: [-36.0105, -21.3604]
# Step 259: Probs sum: 1.0000
# Step 259: Probs max: 1.0000
# Step 259: Next token: 1437
# Step 260: Logits shape: torch.Size([1, 50265])
# Step 260: Logits range: [-36.1366, -21.6034]
# Step 260: Probs sum: 1.0000
# Step 260: Probs max: 1.0000
# Step 260: Next token: 1437
# Step 260: Current sequence length: 262
# ...
# Step 961: Logits shape: torch.Size([1, 50265])
# Step 961: Logits range: [-31.7530, -13.8280]
# Step 961: Probs sum: 1.0000
# Step 961: Probs max: 1.0000
# Step 961: Next token: 6
# Step 962: Logits shape: torch.Size([1, 50265])
# Step 962: Logits range: [-30.1784, -9.8465]
# Step 962: Probs sum: 1.0000
# Step 962: Probs max: 1.0000
# Step 962: Next token: 49049
# Step 963: Logits shape: torch.Size([1, 50265])
# Step 963: Logits range: [-28.5463, -10.3810]
# Step 963: Probs sum: 1.0000
# Step 963: Probs max: 1.0000
# Step 963: Next token: 4
# Step 964: Logits shape: torch.Size([1, 50265])
# Step 964: Logits range: [-22.6019, -2.5103]
# Step 964: Probs sum: 1.0000
# Step 964: Probs max: 1.0000
# Step 964: Next token: 19434
# Step 965: Logits shape: torch.Size([1, 50265])
# Step 965: Logits range: [-32.1574, -14.6741]
# Step 965: Probs sum: 1.0000
# Step 965: Probs max: 1.0000
# Step 965: Next token: 6
# Step 966: Logits shape: torch.Size([1, 50265])
# Step 966: Logits range: [-28.0618, -7.6325]
# Step 966: Probs sum: 1.0000
# Step 966: Probs max: 1.0000
# Step 966: Next token: 19233
# Step 967: Logits shape: torch.Size([1, 50265])
# Step 967: Logits range: [-40.8764, -18.7600]
# Step 967: Probs sum: 1.0000
# Step 967: Probs max: 1.0000
# Step 967: Next token: 33977
# Step 968: Logits shape: torch.Size([1, 50265])
# Step 968: Logits range: [-27.3481, -9.0269]
# Step 968: Probs sum: 1.0000
# Step 968: Probs max: 1.0000
# Step 968: Next token: 4397
# Step 969: Logits shape: torch.Size([1, 50265])
# Step 969: Logits range: [-31.0765, -15.0890]
# Step 969: Probs sum: 1.0000
# Step 969: Probs max: 1.0000
# Step 969: Next token: 50121
# Step 970: Logits shape: torch.Size([1, 50265])
# Step 970: Logits range: [-13.9952, 3.4124]
# Step 970: Probs sum: 1.0000
# Step 970: Probs max: 1.0000
# Step 970: Next token: 50118
# Step 970: Current sequence length: 972
# Step 970: Last 5 tokens: [19233, 33977, 4397, 50121, 50118]
# Step 971: Logits shape: torch.Size([1, 50265])
# Step 971: Logits range: [-35.9176, -21.4424]
# Step 971: Probs sum: 1.0000
# Step 971: Probs max: 1.0000
# Step 971: Next token: 1437
# Step 972: Logits shape: torch.Size([1, 50265])
# Step 972: Logits range: [-35.8094, -21.3886]
# Step 972: Probs sum: 1.0000
# Step 972: Probs max: 1.0000
# Step 972: Next token: 1437
# Step 973: Logits shape: torch.Size([1, 50265])
# Step 973: Logits range: [-34.7175, -20.3390]
# Step 973: Probs sum: 1.0000
# Step 973: Probs max: 1.0000
# Step 973: Next token: 1437
# Step 974: Logits shape: torch.Size([1, 50265])
# Step 974: Logits range: [-21.0500, -2.7176]
# Step 974: Probs sum: 1.0000
# Step 974: Probs max: 1.0000
# Step 974: Next token: 35524
# Step 975: Logits shape: torch.Size([1, 50265])
# Step 975: Logits range: [-30.4712, -14.4512]
# Step 975: Probs sum: 1.0000
# Step 975: Probs max: 1.0000
# Step 975: Next token: 50121
# Step 976: Logits shape: torch.Size([1, 50265])
# Step 976: Logits range: [-13.6124, 3.7542]
# Step 976: Probs sum: 1.0000
# Step 976: Probs max: 1.0000
# Step 976: Next token: 50118
# Step 977: Logits shape: torch.Size([1, 50265])
# Step 977: Logits range: [-31.1679, -15.2330]
# Step 977: Probs sum: 1.0000
# Step 977: Probs max: 1.0000
# Step 977: Next token: 50121
# Step 978: Logits shape: torch.Size([1, 50265])
# Step 978: Logits range: [-14.1128, 3.2503]
# Step 978: Probs sum: 1.0000
# Step 978: Probs max: 1.0000
# Step 978: Next token: 50118
# Step 979: Logits shape: torch.Size([1, 50265])
# Step 979: Logits range: [-35.8403, -21.3522]
# Step 979: Probs sum: 1.0000
# Step 979: Probs max: 1.0000
# Step 979: Next token: 1437
# Step 980: Logits shape: torch.Size([1, 50265])
# Step 980: Logits range: [-35.9862, -21.5093]
# Step 980: Probs sum: 1.0000
# Step 980: Probs max: 1.0000
# Step 980: Next token: 1437
# Step 980: Current sequence length: 982
# Step 980: Last 5 tokens: [50118, 50121, 50118, 1437, 1437]
# Step 981: Logits shape: torch.Size([1, 50265])
# Step 981: Logits range: [-36.0464, -21.4337]
# Step 981: Probs sum: 1.0000
# Step 981: Probs max: 1.0000
# Step 981: Next token: 1437
# Step 982: Logits shape: torch.Size([1, 50265])
# Step 982: Logits range: [-18.9900, 0.2269]
# Step 982: Probs sum: 1.0000
# Step 982: Probs max: 1.0000
# Step 982: Next token: 5043
# Step 983: Logits shape: torch.Size([1, 50265])
# Step 983: Logits range: [-34.8391, -12.6977]
# Step 983: Probs sum: 1.0000
# Step 983: Probs max: 1.0000
# Step 983: Next token: 8202
# Step 984: Logits shape: torch.Size([1, 50265])
# Step 984: Logits range: [-25.3338, -4.6815]
# Step 984: Probs sum: 1.0000
# Step 984: Probs max: 1.0000
# Step 984: Next token: 43048
# Step 985: Logits shape: torch.Size([1, 50265])
# Step 985: Logits range: [-27.2698, -8.1287]
# Step 985: Probs sum: 1.0000
# Step 985: Probs max: 1.0000
# Step 985: Next token: 25522
# Step 986: Logits shape: torch.Size([1, 50265])
# Step 986: Logits range: [-30.6902, -14.7422]
# Step 986: Probs sum: 1.0000
# Step 986: Probs max: 1.0000
# Step 986: Next token: 50121
# Step 987: Logits shape: torch.Size([1, 50265])
# Step 987: Logits range: [-14.5405, 2.7768]
# Step 987: Probs sum: 1.0000
# Step 987: Probs max: 1.0000
# Step 987: Next token: 50118
# Step 988: Logits shape: torch.Size([1, 50265])
# Step 988: Logits range: [-36.2541, -21.7664]
# Step 988: Probs sum: 1.0000
# Step 988: Probs max: 1.0000
# Step 988: Next token: 1437
# Step 989: Logits shape: torch.Size([1, 50265])
# Step 989: Logits range: [-36.0848, -21.4779]
# Step 989: Probs sum: 1.0000
# Step 989: Probs max: 1.0000
# Step 989: Next token: 1437
# Step 990: Logits shape: torch.Size([1, 50265])
# Step 990: Logits range: [-35.8246, -21.1862]
# Step 990: Probs sum: 1.0000
# Step 990: Probs max: 1.0000
# Step 990: Next token: 1437
# Step 990: Current sequence length: 992
# Step 990: Last 5 tokens: [50121, 50118, 1437, 1437, 1437]
# Step 991: Logits shape: torch.Size([1, 50265])
# Step 991: Logits range: [-35.8687, -21.3161]
# Step 991: Probs sum: 1.0000
# Step 991: Probs max: 1.0000
# Step 991: Next token: 1437
# Step 992: Logits shape: torch.Size([1, 50265])
# Step 992: Logits range: [-36.0958, -21.5846]
# Step 992: Probs sum: 1.0000
# Step 992: Probs max: 1.0000
# Step 992: Next token: 1437
# Step 993: Logits shape: torch.Size([1, 50265])
# Step 993: Logits range: [-35.8237, -21.3282]
# Step 993: Probs sum: 1.0000
# Step 993: Probs max: 1.0000
# Step 993: Next token: 1437
# Step 994: Logits shape: torch.Size([1, 50265])
# Step 994: Logits range: [-37.1279, -22.4330]
# Step 994: Probs sum: 1.0000
# Step 994: Probs max: 1.0000
# Step 994: Next token: 1437
# Step 995: Logits shape: torch.Size([1, 50265])
# Step 995: Logits range: [-27.8863, -9.6322]
# Step 995: Probs sum: 1.0000
# Step 995: Probs max: 1.0000
# Step 995: Adding noise to prevent repetition
# Step 995: Next token: 19463
# Step 996: Logits shape: torch.Size([1, 50265])
# Step 996: Logits range: [-28.4499, -10.1761]
# Step 996: Probs sum: 1.0000
# Step 996: Probs max: 1.0000
# Step 996: Next token: 49315
# Step 997: Logits shape: torch.Size([1, 50265])
# Step 997: Logits range: [-23.9808, -5.8306]
# Step 997: Probs sum: 1.0000
# Step 997: Probs max: 1.0000
# Step 997: Next token: 24554
# Step 998: Logits shape: torch.Size([1, 50265])
# Step 998: Logits range: [-25.0186, -5.1734]
# Step 998: Probs sum: 1.0000
# Step 998: Probs max: 1.0000
# Step 998: Next token: 2394
# Step 999: Logits shape: torch.Size([1, 50265])
# Step 999: Logits range: [-35.1179, -16.8456]
# Step 999: Probs sum: 1.0000
# Step 999: Probs max: 1.0000
# Step 999: Next token: 5457
# Step 1000: Logits shape: torch.Size([1, 50265])
# Step 1000: Logits range: [-22.9858, -1.9911]
# Step 1000: Probs sum: 1.0000
# Step 1000: Probs max: 1.0000
# Step 1000: Next token: 42
# Step 1000: Current sequence length: 1002
# Step 1000: Last 5 tokens: [49315, 24554, 2394, 5457, 42]
# Step 1001: Logits shape: torch.Size([1, 50265])
# Step 1001: Logits range: [-29.2038, -10.9069]
# Step 1001: Probs sum: 1.0000
# Step 1001: Probs max: 1.0000
# Step 1001: Next token: 4
# Step 1002: Logits shape: torch.Size([1, 50265])
# Step 1002: Logits range: [-28.7344, -7.9671]
# Step 1002: Probs sum: 1.0000
# Step 1002: Probs max: 1.0000
# Step 1002: Next token: 30821
# Step 1003: Logits shape: torch.Size([1, 50265])
# Step 1003: Logits range: [-27.7977, -10.5699]
# Step 1003: Probs sum: 1.0000
# Step 1003: Probs max: 1.0000
# Step 1003: Next token: 131
# Step 1004: Logits shape: torch.Size([1, 50265])
# Step 1004: Logits range: [-31.2036, -15.2433]
# Step 1004: Probs sum: 1.0000
# Step 1004: Probs max: 1.0000
# Step 1004: Next token: 50121
# Step 1005: Logits shape: torch.Size([1, 50265])
# Step 1005: Logits range: [-14.3686, 2.9254]
# Step 1005: Probs sum: 1.0000
# Step 1005: Probs max: 1.0000
# Step 1005: Next token: 50118
# Step 1006: Logits shape: torch.Size([1, 50265])
# Step 1006: Logits range: [-35.6064, -21.0397]
# Step 1006: Probs sum: 1.0000
# Step 1006: Probs max: 1.0000
# Step 1006: Next token: 1437
# Step 1007: Logits shape: torch.Size([1, 50265])
# Step 1007: Logits range: [-35.6805, -21.0840]
# Step 1007: Probs sum: 1.0000
# Step 1007: Probs max: 1.0000
# Step 1007: Next token: 1437
# Step 1008: Logits shape: torch.Size([1, 50265])
# Step 1008: Logits range: [-35.6134, -21.1297]
# Step 1008: Probs sum: 1.0000
# Step 1008: Probs max: 1.0000
# Step 1008: Next token: 1437
# Step 1009: Logits shape: torch.Size([1, 50265])
# Step 1009: Logits range: [-35.3565, -20.9200]
# Step 1009: Probs sum: 1.0000
# Step 1009: Probs max: 1.0000
# Step 1009: Next token: 1437
# Step 1010: Logits shape: torch.Size([1, 50265])
# Step 1010: Logits range: [-35.5596, -21.1795]
# Step 1010: Probs sum: 1.0000
# Step 1010: Probs max: 1.0000
# Step 1010: Next token: 1437
# Step 1010: Current sequence length: 1012
# Step 1010: Last 5 tokens: [1437, 1437, 1437, 1437, 1437]
# Step 1011: Logits shape: torch.Size([1, 50265])
# Step 1011: Logits range: [-35.5078, -21.1755]
# Step 1011: Probs sum: 1.0000
# Step 1011: Probs max: 1.0000
# Step 1011: Next token: 1437
# Step 1012: Logits shape: torch.Size([1, 50265])
# Step 1012: Logits range: [-37.1886, -20.1479]
# Step 1012: Probs sum: 1.0000
# Step 1012: Probs max: 1.0000
# Step 1012: Next token: 1437
# Step 1013: Logits shape: torch.Size([1, 50265])
# Step 1013: Logits range: [-30.7485, -6.6673]
# Step 1013: Probs sum: 1.0000
# Step 1013: Probs max: 1.0000
# Step 1013: Adding noise to prevent repetition
# Step 1013: Next token: 9034
# Step 1014: Logits shape: torch.Size([1, 50265])
# Step 1014: Logits range: [-39.0734, -16.9989]
# Step 1014: Probs sum: 1.0000
# Step 1014: Probs max: 1.0000
# Step 1014: Next token: 2684
# Step 1015: Logits shape: torch.Size([1, 50265])
# Step 1015: Logits range: [-39.2941, -16.6773]
# Step 1015: Probs sum: 1.0000
# Step 1015: Probs max: 1.0000
# Step 1015: Next token: 725
# Step 1016: Logits shape: torch.Size([1, 50265])
# Step 1016: Logits range: [-33.9220, -9.6421]
# Step 1016: Probs sum: 1.0000
# Step 1016: Probs max: 1.0000
# Step 1016: Next token: 33780
# Step 1017: Logits shape: torch.Size([1, 50265])
# Step 1017: Logits range: [-31.5677, -13.4599]
# Step 1017: Probs sum: 1.0000
# Step 1017: Probs max: 1.0000
# Step 1017: Next token: 4
# Step 1018: Logits shape: torch.Size([1, 50265])
# Step 1018: Logits range: [-25.9745, -6.3822]
# Step 1018: Probs sum: 1.0000
# Step 1018: Probs max: 1.0000
# Step 1018: Next token: 40095
# Step 1019: Logits shape: torch.Size([1, 50265])
# Step 1019: Logits range: [-31.1744, -12.9253]
# Step 1019: Probs sum: 1.0000
# Step 1019: Probs max: 1.0000
# Step 1019: Next token: 1640
# Step 1020: Logits shape: torch.Size([1, 50265])
# Step 1020: Logits range: [-30.2016, -9.4816]
# Step 1020: Probs sum: 1.0000
# Step 1020: Probs max: 1.0000
# Step 1020: Next token: 30821
# Step 1020: Current sequence length: 1022
# Step 1020: Last 5 tokens: [33780, 4, 40095, 1640, 30821]
# Step 1021: Logits shape: torch.Size([1, 50265])
# Step 1021: Logits range: [-26.9844, -8.6684]
# Step 1021: Probs sum: 1.0000
# Step 1021: Probs max: 1.0000
# Step 1021: Next token: 4397
# Step 1022: Logits shape: torch.Size([1, 50265])
# Step 1022: Logits range: [-24.1886, -5.9850]
# Step 1022: Probs sum: 1.0000
# Step 1022: Probs max: 1.0000
# Step 1022: Next token: 2
# Stopping at step 1022 due to EOS/PAD token
# Final generated sequence shape: torch.Size([1, 1024])
# Final sequence tokens: [0, 4862, 1073, 1916, 2705, 1571, 37249, 288, 4, 306, 4, 1646, 131, 50121, 50118, 50121, 50118, 31938, 11056, 45643, 25522, 50121, 50118, 1437, 1437, 1437, 6755, 285, 766, 131, 50121, 50118, 1437, 1437, 1437, 6755, 285, 7648, 131, 50121, 50118, 1437, 1437, 1437, 49315, 398, 285, 5044, 757, 1536, 131, 50121, 50118, 1437, 1437, 1437, 49315, 24554, 285, 746, 33661, 352, 131, 50121, 50118, 50121, 50118, 1437, 1437, 1437, 20410, 36, 44547, 46161, 49315, 24554, 43, 285, 2394, 10643, 131, 50121, 50118, 1437, 1437, 1437, 20410, 36, 44547, 46161, 20410, 36, 44547, 46161, 49315, 24554, 35122, 285, 19488, 131, 50121, 50118, 50121, 50118, 1437, 1437, 1437, 515, 18853, 1640, 44547, 43220, 31, 6, 1100, 43220, 7, 6, 49315, 24554, 923, 4397, 50121, 50118, 1437, 1437, 1437, 515, 23236, 6486, 1640, 44547, 43220, 1945, 6, 1100, 43220, 2292, 7232, 6, 49315, 24554, 923, 4397, 50121, 50118, 50121, 50118, 1437, 1437, 1437, 5043, 18134, 40095, 1640, 44547, 18134, 7761, 6, 1100, 18134, 560, 6, 49315, 18134, 19434, 43, 3425, 25522, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 1541, 49604, 560, 49333, 321, 1178, 288, 4397, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 17885, 2703, 1640, 30821, 10643, 49895, 7761, 742, 49095, 18134, 19434, 4397, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 2703, 1640, 30821, 10643, 49895, 560, 742, 2055, 18134, 19434, 8061, 2394, 10643, 49895, 560, 48601, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 10567, 49315, 986, 35917, 5332, 5457, 2394, 10643, 49895, 7761, 742, 2055, 2394, 10643, 49895, 560, 44082, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 2394, 10643, 49895, 7761, 742, 49826, 18134, 19434, 131, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 23274, 10643, 49895, 560, 742, 49371, 18134, 19434, 131, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 33845, 1640, 30821, 10643, 49895, 7761, 742, 2055, 2394, 10643, 49895, 560, 742, 45994, 986, 35917, 5332, 4397, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 15322, 49604, 7761, 6, 18134, 560, 6, 18134, 19434, 4397, 50121, 50118, 1437, 1437, 1437, 35524, 50121, 50118, 50121, 50118, 1437, 1437, 1437, 5043, 2937, 1640, 44547, 18134, 560, 6, 49315, 24554, 18134, 19434, 43, 285, 2886, 36, 46787, 1282, 43, 25522, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 38695, 1640, 48593, 4, 29, 7232, 6, 18134, 560, 6, 18134, 19434, 4397, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 7561, 671, 1528, 131, 50121, 50118, 1437, 1437, 1437, 35524, 50121, 50118, 50121, 50118, 1437, 1437, 1437, 5043, 2937, 7605, 1640, 44547, 18134, 7761, 6, 1100, 18134, 560, 6, 49315, 24554, 18134, 19434, 43, 285, 2886, 36, 46787, 1282, 43, 25522, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 35690, 2703, 49604, 19434, 49230, 19488, 49895, 7761, 46386, 48593, 4, 29, 7232, 48601, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 19488, 49895, 7761, 46386, 48593, 4, 29, 7232, 742, 49826, 18134, 19434, 131, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 17199, 49604, 7761, 6, 18134, 560, 6, 18134, 19434, 4397, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 38765, 671, 1528, 131, 50121, 50118, 1437, 1437, 1437, 35524, 50121, 50118, 50121, 50118, 1437, 1437, 1437, 5043, 7244, 1640, 44547, 18134, 4182, 7232, 6, 49315, 24554, 18134, 19434, 43, 285, 2886, 36, 46787, 1282, 43, 25522, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 44574, 19488, 10975, 48593, 4, 29, 7232, 46386, 1215, 4182, 7232, 742, 5457, 18134, 19434, 131, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 23236, 6486, 1640, 48593, 4, 29, 7232, 6, 18134, 4182, 7232, 6, 18134, 19434, 4397, 50121, 50118, 1437, 1437, 1437, 1437, 1437, 1437, 1437, 41791, 131, 50121, 50118, 1437, 1437, 1437, 1437, 35524, 50121, 50118, 24303, 50121, 50118, 50121, 50118, 31938, 8242, 3293, 22036, 16, 11056, 45643, 25522, 50121, 50118, 1437, 1437, 1437, 21277, 112, 41014, 5457, 1437, 2684, 40855, 1020, 19233, 50121, 50118, 1437, 1 ...
# Generated code length: 2565
# Generated code preview: pragma solidity ^0.4.19;
#
# contract BaseToken {
#     string public name;
#     string public symbol;
#     uint8 public decimals;
#     uint256 public totalSupply;
#
#     mapping (address => uint256) pu...
# Successfully generated contract 1

# %%
result
# Out:
# {'contract_name': 'Contract_0',
#  'batch_idx': 0,
#  'source_code': "pragma solidity ^0.4.19;\r\n\r\ncontract BaseToken {\r\n    string public name;\r\n    string public symbol;\r\n    uint8 public decimals;\r\n    uint256 public totalSupply;\r\n\r\n    mapping (address => uint256) public balanceOf;\r\n    mapping (address => mapping (address => uint256)) public allowance;\r\n\r\n    event Transfer(address indexed from, address indexed to, uint256 value);\r\n    event Approval(address indexed owner, address indexed spender, uint256 value);\r\n\r\n    function _transfer(address _from, address _to, uint _value) internal {\r\n        require(_to != 0x0);\r\n        require(balanceOf[_from] >= _value);\r\n        require(balanceOf[_to] + _value > balanceOf[_to]);\r\n        uint previousBalances = balanceOf[_from] + balanceOf[_to];\r\n        balanceOf[_from] -= _value;\r\n        balanceOf[_to] += _value;\r\n        assert(balanceOf[_from] + balanceOf[_to] == previousBalances);\r\n        Transfer(_from, _to, _value);\r\n    }\r\n\r\n    function transfer(address _to, uint256 _value) public returns (bool success) {\r\n        _transfer(msg.sender, _to, _value);\r\n        return true;\r\n    }\r\n\r\n    function transferFrom(address _from, address _to, uint256 _value) public returns (bool success) {\r\n        require(_value <= allowance[_from][msg.sender]);\r\n        allowance[_from][msg.sender] -= _value;\r\n        _transfer(_from, _to, _value);\r\n        return true;\r\n    }\r\n\r\n    function approve(address _spender, uint256 _value) public returns (bool success) {\r\n        allowance[msg.sender][_spender] = _value;\r\n        Approval(msg.sender, _spender, _value);\r\n        return true;\r\n    }\r\n}\r\n\r\ncontract ICOToken is BaseToken {\r\n    // 1 ether = icoRatio token\r\n    uint256 public icoRatio;\r\n    uint256 public icoEndtime;\r\n    address public icoSender;\r\n    address public icoHolder;\r\n\r\n    event ICO(address indexed from, uint256 indexed value, uint256 tokenValue);\r\n    event Withdraw(address indexed from, address indexed holder, uint256 value);\r\n\r\n    modifier onlyBefore() {\r\n        if (now > icoEndtime) {\r\n            revert();\r\n        }\r\n        _;\r\n    }\r\n\r\n    function() public payable onlyBefore {\r\n        uint256 tokenValue = (msg.value * icoRatio * 10 ** uint256(decimals)) / (1 ether / 1 wei);\r\n        if (tokenValue == 0 || balanceOf[icoSender] < tokenValue) {\r\n            revert();\r\n        }\r\n        _transfer(icoSender, msg.sender, tokenValue);\r\n        ICO(msg.sender, msg.value, tokenValue);\r\n    }\r\n\r\n    function withdraw() {\r\n        uint256 balance = this.balance;\r\n        icoHolder.transfer(balance);\r\n        Withdraw(msg.sender, icoHolder, balance);\r\n    }\r\n}\r\n\r\ncontract CustomToken is BaseToken, ICOToken {\r\n    function CustomToken() public {\r\n        totalSupply = 2100000000000000;\r\n        balanceOf[0x1dd91123acc8a51392b35b310b2f0bed6ff082f2] = totalSupply;\r\n        name = 'freeandcoin';\r\n        symbol = 'YHB';\r\n        decimals = 8;\r\n        icoRatio = 10000;\r\n        icoEndtime = 1830268800;\r\n        icoSender = 0x723751481f1133d012e96209c88fc81ecdaca083;\r\n        icoHolder = 0x723751481f1133d012e96209c88fc81ecdaca083;\r\n    }\r\n}",
#  'true_contract_vulnerabilities': [1, 0, 0, 1, 1, 0, 0, 0],
#  'predicted_contract_vulnerabilities': [1, 0, 0, 0, 0, 0, 0, 0],
#  'contract_probabilities': [0.6988602876663208,
#   0.3253549337387085,
#   0.33602529764175415,
#   0.4469253420829773,
#   0.3218841254711151,
#   0.312606543302536,
#   0.0016224278369918466,
#   0.28679636120796204],
#  'contract_accuracy': 0.75,
#  'contract_precision': 1.0,
#  'contract_recall': 0.3333333333333333,
#  'contract_f1': 0.5,
#  'line_accuracy': 0.99951171875,
#  'vulnerability_details': {'ARTHM': {'true_positive': True,
#    'false_positive': False,
#    'false_negative': False,
#    'true_negative': False,
#    'probability': 0.6988602876663208,
#    'true_label': 1,
#    'predicted_label': 1},
#   'DOS': {'true_positive': False,
#    'false_positive': False,
#    'false_negative': False,
#    'true_negative': True,
#    'probability': 0.3253549337387085,
#    'true_label': 0,
#    'predicted_label': 0},
#   'LE': {'true_positive': False,
#    'false_positive': False,
#    'false_negative': False,
#    'true_negative': True,
#    'probability': 0.33602529764175415,
#    'true_label': 0,
#    'predicted_label': 0},
#   'RENT': {'true_positive': False,
#    'false_positive': False,
#    'false_negative': True,
#    'true_negative': False,
#    'probability': 0.4469253420829773,
#    'true_label': 1,
#    'predicted_label': 0},
#   'TimeM': {'true_positive': False,
#    'false_positive': False,
#    'false_negative': True,
#    'true_negative': False,
#    'probability': 0.3218841254711151,
#    'true_label': 1,
#    'predicted_label': 0},
#   'TimeO': {'true_positive': False,
#    'false_positive': False,
#    'false_negative': False,
#    'true_negative': True,
#    'probability': 0.312606543302536,
#    'true_label': 0,
#    'predicted_label': 0},
#   'Tx-Origin': {'true_positive': False,
#    'false_positive': False,
#    'false_negative': False,
#    'true_negative': True,
#    'probability': 0.0016224278369918466,
#    'true_label': 0,
#    'predicted_label': 0},
#   'UE': {'true_positive': False,
#    'false_positive': False,
#    'false_negative': False,
#    'true_negative': True,
#    'probability': 0.28679636120796204,
#    'true_label': 0,
#    'predicted_label': 0}},
#  'generated_contract': ["// Generated contract based on template\npragma solidity ^0.4.19;\r\n\r\ncontract BaseToken {\r\n    string public name;\r\n    string public symbol;\r\n    uint8 public decimals;\r\n    uint256 public totalSupply;\r\n\r\n    mapping (address => uint256) public balanceOf;\r\n    mapping (address => mapping (address => uint256)) public allowance;\r\n\r\n    event Transfer(address indexed from, address indexed to, uint256 value);\r\n    event Approval(address indexed owner, address indexed spender, uint256 value);\r\n\r\n    function _transfer(address _from, address _to, uint _value) internal {\r\n        require(_to != 0x0);\r\n        require(balanceOf[_from] >= _value);\r\n        require(balanceOf[_to] + _value > balanceOf[_to]);\r\n        uint previousBalances = balanceOf[_from] + balanceOf[_to];\r\n        balanceOf[_from] -= _value;\r\n        balanceOf[_to] += _value;\r\n        assert(balanceOf[_from] + balanceOf[_to] == previousBalances);\r\n        Transfer(_from, _to, _value);\r\n    }\r\n\r\n    function transfer(address _to, uint256 _value) public returns (bool success) {\r\n        _transfer(msg.sender, _to, _value);\r\n        return true;\r\n    }\r\n\r\n    function transferFrom(address _from, address _to, uint256 _value) public returns (bool success) {\r\n        require(_value <= allowance[_from][msg.sender]);\r\n        allowance[_from][msg.sender] -= _value;\r\n        _transfer(_from, _to, _value);\r\n        return true;\r\n    }\r\n\r\n    function approve(address _spender, uint256 _value) public returns (bool success) {\r\n        allowance[msg.sender][_spender] = _value;\r\n        Approval(msg.sender, _spender, _value);\r\n        return true;\r\n    }\r\n}\r\n\r\ncontract ICOToken is BaseToken {\r\n    // 1 ether = icoRatio token\r\n    uint256 public icoRatio;\r\n    uint256 public icoEndtime;\r\n    address public icoSender;\r\n    address public icoHolder;\r\n\r\n    event ICO(address indexed from, uint256 indexed value, uint256 tokenValue);\r\n    event Withdraw(address indexed from, address indexed holder, uint256 value);\r\n\r\n    modifier onlyBefore() {\r\n        if (now > icoEndtime) {\r\n            revert();\r\n        }\r\n        _;\r\n    }\r\n\r\n    function() public payable onlyBefore {\r\n        uint256 tokenValue = (msg.value * icoRatio * 10 ** uint256(decimals)) / (1 ether / 1 wei);\r\n        if (tokenValue == 0 || balanceOf[icoSender] < tokenValue) {\r\n            revert();\r\n        }\r\n        _transfer(icoSender, msg.sender, tokenValue);\r\n        ICO(msg.sender, msg.value, tokenValue);\r\n    }\r\n\r\n    function withdraw() {\r\n        uint256 balance = this.balance;\r\n        icoHolder.transfer(balance);\r\n        Withdraw(msg.sender, icoHolder, balance);\r\n    }\r\n}\r\n\r\ncontract CustomToken is BaseToken, ICOToken {\r\n    function CustomToken() public {\r\n        totalSupply = 2100000000000000;\r\n        balanceOf[0x1dd91123acc8a51392b35b310b2f0bed6ff082f2] = totalSupply;\r\n        name = 'freeandcoin';\r\n        symbol = 'YHB';\r\n        decimals = 8;\r\n        icoRatio = 10000;\r\n        icoEndtime = 1830268800;\r\n        icoSender = 0x723751481f1133d012e96209c88fc81ecdaca083;\r\n        icoHolder = 0x723751481f1133d012e96209c88fc81ecdaca083;\r\n    }\r\n}",
#   "// Generated contract based on template\npragma solidity ^0.4.19;\r\n\r\ncontract BaseToken {\r\n    string public name;\r\n    string public symbol;\r\n    uint8 public decimals;\r\n    uint256 public totalSupply;\r\n\r\n    mapping (address => uint256) public balanceOf;\r\n    mapping (address => mapping (address => uint256)) public allowance;\r\n\r\n    event Transfer(address indexed from, address indexed to, uint256 value);\r\n    event Approval(address indexed owner, address indexed spender, uint256 value);\r\n\r\n    function _transfer(address _from, address _to, uint _value) internal {\r\n        require(_to != 0x0);\r\n        require(balanceOf[_from] >= _value);\r\n        require(balanceOf[_to] + _value > balanceOf[_to]);\r\n        uint previousBalances = balanceOf[_from] + balanceOf[_to];\r\n        balanceOf[_from] -= _value;\r\n        balanceOf[_to] += _value;\r\n        assert(balanceOf[_from] + balanceOf[_to] == previousBalances);\r\n        Transfer(_from, _to, _value);\r\n    }\r\n\r\n    function transfer(address _to, uint256 _value) public returns (bool success) {\r\n        _transfer(msg.sender, _to, _value);\r\n        return true;\r\n    }\r\n\r\n    function transferFrom(address _from, address _to, uint256 _value) public returns (bool success) {\r\n        require(_value <= allowance[_from][msg.sender]);\r\n        allowance[_from][msg.sender] -= _value;\r\n        _transfer(_from, _to, _value);\r\n        return true;\r\n    }\r\n\r\n    function approve(address _spender, uint256 _value) public returns (bool success) {\r\n        allowance[msg.sender][_spender] = _value;\r\n        Approval(msg.sender, _spender, _value);\r\n        return true;\r\n    }\r\n}\r\n\r\ncontract ICOToken is BaseToken {\r\n    // 1 ether = icoRatio token\r\n    uint256 public icoRatio;\r\n    uint256 public icoEndtime;\r\n    address public icoSender;\r\n    address public icoHolder;\r\n\r\n    event ICO(address indexed from, uint256 indexed value, uint256 tokenValue);\r\n    event Withdraw(address indexed from, address indexed holder, uint256 value);\r\n\r\n    modifier onlyBefore() {\r\n        if (now > icoEndtime) {\r\n            revert();\r\n        }\r\n        _;\r\n    }\r\n\r\n    function() public payable onlyBefore {\r\n        uint256 tokenValue = (msg.value * icoRatio * 10 ** uint256(decimals)) / (1 ether / 1 wei);\r\n        if (tokenValue == 0 || balanceOf[icoSender] < tokenValue) {\r\n            revert();\r\n        }\r\n        _transfer(icoSender, msg.sender, tokenValue);\r\n        ICO(msg.sender, msg.value, tokenValue);\r\n    }\r\n\r\n    function withdraw() {\r\n        uint256 balance = this.balance;\r\n        icoHolder.transfer(balance);\r\n        Withdraw(msg.sender, icoHolder, balance);\r\n    }\r\n}\r\n\r\ncontract CustomToken is BaseToken, ICOToken {\r\n    function CustomToken() public {\r\n        totalSupply = 2100000000000000;\r\n        balanceOf[0x1dd91123acc8a51392b35b310b2f0bed6ff082f2] = totalSupply;\r\n        name = 'freeandcoin';\r\n        symbol = 'YHB';\r\n        decimals = 8;\r\n        icoRatio = 10000;\r\n        icoEndtime = 1830268800;\r\n        icoSender = 0x723751481f1133d012e96209c88fc81ecdaca083;\r\n        icoHolder = 0x723751481f1133d012e96209c88fc81ecdaca083;\r\n    }\r\n}"]}

# %%
print(source_code)
# Out:
# pragma solidity ^0.4.19;
#
# contract BaseToken {
#     string public name;
#     string public symbol;
#     uint8 public decimals;
#     uint256 public totalSupply;
#
#     mapping (address => uint256) public balanceOf;
#     mapping (address => mapping (address => uint256)) public allowance;
#
#     event Transfer(address indexed from, address indexed to, uint256 value);
#     event Approval(address indexed owner, address indexed spender, uint256 value);
#
#     function _transfer(address _from, address _to, uint _value) internal {
#         require(_to != 0x0);
#         require(balanceOf[_from] >= _value);
#         require(balanceOf[_to] + _value > balanceOf[_to]);
#         uint previousBalances = balanceOf[_from] + balanceOf[_to];
#         balanceOf[_from] -= _value;
#         balanceOf[_to] += _value;
#         assert(balanceOf[_from] + balanceOf[_to] == previousBalances);
#         Transfer(_from, _to, _value);
#     }
#
#     function transfer(address _to, uint256 _value) public returns (bool success) {
#         _transfer(msg.sender, _to, _value);
#         return true;
#     }
#
#     function transferFrom(address _from, address _to, uint256 _value) public returns (bool success) {
#         require(_value <= allowance[_from][msg.sender]);
#         allowance[_from][msg.sender] -= _value;
#         _transfer(_from, _to, _value);
#         return true;
#     }
#
#     function approve(address _spender, uint256 _value) public returns (bool success) {
#         allowance[msg.sender][_spender] = _value;
#         Approval(msg.sender, _spender, _value);
#         return true;
#     }
# }
#
# contract ICOToken is BaseToken {
#     // 1 ether = icoRatio token
#     uint256 public icoRatio;
#     uint256 public icoEndtime;
#     address public icoSender;
#     address public icoHolder;
#
#     event ICO(address indexed from, uint256 indexed value, uint256 tokenValue);
#     event Withdraw(address indexed from, address indexed holder, uint256 value);
#
#     modifier onlyBefore() {
#         if (now > icoEndtime) {
#             revert();
#         }
#         _;
#     }
#
#     function() public payable onlyBefore {
#         uint256 tokenValue = (msg.value * icoRatio * 10 ** uint256(decimals)) / (1 ether / 1 wei);
#         if (tokenValue == 0 || balanceOf[icoSender] < tokenValue) {
#             revert();
#         }
#         _transfer(icoSender, msg.sender, tokenValue);
#         ICO(msg.sender, msg.value, tokenValue);
#     }
#
#     function withdraw() {
#         uint256 balance = this.balance;
#         icoHolder.transfer(balance);
#         Withdraw(msg.sender, icoHolder, balance);
#     }
# }
#
# contract CustomToken is BaseToken, ICOToken {
#     function CustomToken() public {
#         totalSupply = 2100000000000000;
#         balanceOf[0x1dd91123acc8a51392b35b310b2f0bed6ff082f2] = totalSupply;
#         name = 'freeandcoin';
#         symbol = 'YHB';
#         decimals = 8;
#         icoRatio = 10000;
#         icoEndtime = 1830268800;
#         icoSender = 0x723751481f1133d012e96209c88fc81ecdaca083;
#         icoHolder = 0x723751481f1133d012e96209c88fc81ecdaca083;
#     }
# }

# %%
print(generated_contracts[0])
# Out:
# pragma solidity ^0.4.19;
#
# contract BaseToken {
#     string public name;
#     string public symbol;
#     uint8 public decimals;
#     uint256 public totalSupply;
#
#     mapping (address => uint256) public balanceOf;
#     mapping (address => mapping (address => uint256)) public allowance;
#
#     event Transfer(address indexed from, address indexed to, uint256 value);
#     event Approval(address indexed owner, address indexed spender, uint256 value);
#
#     function _transfer(address _from, address _to, uint _value) internal {
#         Our(_to!= 0x0);
#         ratios require(balanceOf[_from] >= _value);
#        require(balanceOf[_to] + _value > balanceOf[_to]);
#        John uint previousBalances = balanceOf[_from] + balanceOf[_to];
#        balanceOf[_from] -= _value;
#        beitOf[_to] += _value;
#        db(balanceOf[_from] + balanceOf[_to] == previousBalances);
#        athan(_from, _to, _value);
#     }
#
#     function transfer(address _to, uint256 _value) public returns (bool success) {
#         eras(msg.sender, _to, _value);
#        PH return true;
#     }
#
#     function transferFrom(address _from, address _to, uint256 _value) public returns (bool success) {
#         TF require(_value <= allowance[_from][msg.sender]);
#        allowance[_from][msg.sender] -= _value;
#         uploaded(_from, _to, _value);
#        733 return true;
#     }
#
#     function approve(address _spender, uint256 _value) public returns (bool success) {
#        的 allowance[msg.sender][_spender] = _value;
#        Approval(msg.sender, _spender, _value);
#        tick;
#      }
# }
#
# contract ICOToken is BaseToken {
#     // 1 ether = icoRatio token
#     uint256 public icoRatio;
#     uint256 public icoEndtime;
#     address public icoSender;
#     address public icoHolder;
#
#     event ICO(address indexed from, uint256 indexed value, uint256 tokenValue);
#     event Withdraw(address indexed from, address indexed holder, uint256 value);
#
#     modifier onlyBefore() {
#         harassment if (now > icoEndtime) {
#        edged   revert();
#         Browne }
#        _;
#     }
#
#     function() public payable onlyBefore {
#         javascript uint256 tokenValue = (msg.value * icoRatio * 10 ** uint256(decimals)) / (1 ether / 1 wei);
#        if (tokenValue == 0 || balanceOf[icoSender] < tokenValue) {
#         Hive    revert();
#        One }
#        _transfer(icoSender, msg.sender, tokenValue);
#         Sud(msg.sender, msg.value, tokenValue);
#     }
#
#     function withdraw() {
#         shuttle uint256 balance = this.balance;
#         TehranicoHolder.transfer(balance);

# %%
analyzer = SmartContractAnalyzer("checkpoints/best_model.pt")
result = analyzer.test_generation_simple(template)
print(result)

# %%
output_layer = analyzer.model.output_layer
weights = output_layer.weight.data
bias = output_layer.bias.data

print(f"Output layer shape: {weights.shape}")
print(f"Output layer weight stats:")
print(f"  Mean: {weights.mean().item():.6f}")
print(f"  Std: {weights.std().item():.6f}")
print(f"  Min: {weights.min().item():.6f}")
print(f"  Max: {weights.max().item():.6f}")

print(f"Output layer bias stats:")
print(f"  Mean: {bias.mean().item():.6f}")
print(f"  Std: {bias.std().item():.6f}")
print(f"  Min: {bias.min().item():.6f}")
print(f"  Max: {bias.max().item():.6f}")

# Check if weights are all the same (indicating poor training)
weight_variance = weights.var().item()
bias_variance = bias.var().item()

print(f"Weight variance: {weight_variance:.6f}")
print(f"Bias variance: {bias_variance:.6f}")

if weight_variance < 1e-6:
    print("⚠️  WARNING: Output layer weights have very low variance - model may not be properly trained for generation")

if bias_variance < 1e-6:
    print("⚠️  WARNING: Output layer bias has very low variance - model may not be properly trained for generation")

# Test a simple forward pass
print("\n=== Testing Simple Forward Pass ===")
test_input = torch.randint(0, 1000, (1, 10)).to(analyzer.device)
test_attention = torch.ones(1, 10).to(analyzer.device)

try:
    with torch.no_grad():
        # Test encoder
        test_emb = analyzer.model.embedding(test_input) * math.sqrt(analyzer.model.d_model)
        test_emb = analyzer.model.embedding_dropout(test_emb)
        test_emb = analyzer.model.embedding_norm(test_emb)
        test_emb = analyzer.model.pos_encoder(test_emb.transpose(0, 1)).transpose(0, 1)
        
        memory = analyzer.model.encoder(test_emb, src_key_padding_mask=~test_attention.bool())
        
        # Test decoder with single token
        tgt = torch.full((1, 1), 0, dtype=torch.long, device=analyzer.device)
        tgt_emb = analyzer.model.embedding(tgt) * math.sqrt(analyzer.model.d_model)
        tgt_emb = analyzer.model.embedding_dropout(tgt_emb)
        tgt_emb = analyzer.model.embedding_norm(tgt_emb)
        tgt_emb = analyzer.model.pos_encoder(tgt_emb.transpose(0, 1)).transpose(0, 1)
        
        out = analyzer.model.decoder(
            tgt_emb,
            memory,
            tgt_mask=None,
            memory_key_padding_mask=~test_attention.bool()
        )
        
        out = analyzer.model.output_norm(out)
        out = analyzer.model.output_dropout(out)
        logits = analyzer.model.output_layer(out[:, -1, :])
        
        print(f"Test logits shape: {logits.shape}")
        print(f"Test logits range: [{logits.min().item():.4f}, {logits.max().item():.4f}]")
        
        # Check if logits are reasonable
        probs = torch.softmax(logits, dim=-1)
        print(f"Test probs sum: {probs.sum().item():.4f}")
        print(f"Test probs max: {probs.max().item():.4f}")
        
        # Check top predictions
        top_probs, top_indices = torch.topk(probs, 5, dim=-1)
        print(f"Top 5 token probabilities: {top_probs[0].tolist()}")
        print(f"Top 5 token indices: {top_indices[0].tolist()}")
        
        # Check if token 1 is always the top prediction
        if top_indices[0, 0] == 1:
            print("⚠️  WARNING: Token 1 is the top prediction - this explains the all-1 generation issue")
        else:
            print("✅ Token 1 is not the top prediction - model should generate diverse tokens")
            
except Exception as e:
    print(f"Error during test forward pass: {str(e)}")

print("=== Diagnosis Complete ===")
# Out:
# Output layer shape: torch.Size([50265, 768])
# Output layer weight stats:
#   Mean: -0.004437
#   Std: 0.102096
#   Min: -1.941332
#   Max: 2.517758
# Output layer bias stats:
#   Mean: -3.233994
#   Std: 0.944389
#   Min: -3.701849
#   Max: 2.135393
# Weight variance: 0.010424
# Bias variance: 0.891871
#
# === Testing Simple Forward Pass ===
# Test logits shape: torch.Size([1, 50265])
# Test logits range: [-24.1880, -9.9746]
# Test probs sum: 1.0000
# Test probs max: 0.1560
# Top 5 token probabilities: [0.15604272484779358, 0.053808506578207016, 0.001391868805512786, 0.0006813530344516039, 0.00045423494884744287]
# Top 5 token indices: [1, 163, 1437, 846, 10975]
# ⚠️  WARNING: Token 1 is the top prediction - this explains the all-1 generation issue
# === Diagnosis Complete ===

# %%
    results = analyzer.detect_vulnerabilities(contract_code)
    
    print("\n=== Smart Contract Vulnerability Analysis ===")
    
    # Contract-level vulnerabilities
    print("\n📋 Contract-Level Vulnerabilities:")
    contract_vulns = results['contract_vulnerabilities']
    for vuln_type, is_vulnerable in contract_vulns.items():
        status = "❌ VULNERABLE" if is_vulnerable else "✅ SAFE"
        print(f"  {vuln_type}: {status}")
    
    # Line-level vulnerabilities
    print("\n📝 Line-Level Vulnerabilities:")
    line_vulns = results['line_vulnerabilities']
    lines = contract_code.strip().split('\n')
    
    for line_num, line in enumerate(lines):
        if line.strip():  # Only show non-empty lines
            line_vulns_for_line = line_vulns.get(line_num, {})
            vulnerable_types = [vuln_type for vuln_type, is_vuln in line_vulns_for_line.items() if is_vuln]
            
            if vulnerable_types:
                print(f"  Line {line_num + 1}: ❌ {', '.join(vulnerable_types)}")
                print(f"    Code: {line.strip()}")
            else:
                print(f"  Line {line_num + 1}: ✅ SAFE")
    
    # Probabilities summary
    print("\n📊 Vulnerability Probabilities:")
    contract_probs = results['contract_probabilities'][0]  # First (and only) contract
    for i, vuln_type in enumerate(analyzer.vulnerability_types):
        prob = contract_probs[i]
        print(f"  {vuln_type}: {prob:.4f} ({prob*100:.2f}%)")
    
    # Generate synthetic contracts
    print("\n🔧 Generating Synthetic Contracts...")
    synthetic_contracts = analyzer.generate_synthetic_contract(
        contract_template=contract_code,
        num_contracts=2
    )
    
    print("\n📄 Generated Contracts:")
    for i, contract in enumerate(synthetic_contracts, 1):
        print(f"\n--- Contract {i} ---")
        print(contract)
        
        # Analyze generated contract
        print(f"\n🔍 Analysis of Generated Contract {i}:")
        gen_results = analyzer.detect_vulnerabilities(contract)
        gen_contract_vulns = gen_results['contract_vulnerabilities']
        
        for vuln_type, is_vulnerable in gen_contract_vulns.items():
            status = "❌ VULNERABLE" if is_vulnerable else "✅ SAFE"
            print(f"  {vuln_type}: {status}")

# %%
main()
# Out:
# Using device: cuda
# /home/m20180848/.conda/envs/pytorch_p310/lib/python3.10/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/m20180848/.conda/envs/pytorch_p310/lib/python3.10/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Model loaded from checkpoints_v2_2048_output/best_model_epoch_126.pt
# Training epoch: 126
# Best validation loss: 1.448835600167513
# Warning: Parameter embedding.weight is on cuda:0, moving to cuda
# Warning: Parameter embedding_norm.weight is on cuda:0, moving to cuda
# Warning: Parameter embedding_norm.bias is on cuda:0, moving to cuda
# Warning: Parameter ast_embedding.weight is on cuda:0, moving to cuda
# Warning: Parameter ast_embedding_norm.weight is on cuda:0, moving to cuda
# Warning: Parameter ast_embedding_norm.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.0.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.1.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.2.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.3.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.4.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter encoder.layers.5.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.multihead_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.multihead_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.multihead_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.multihead_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.norm3.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.0.norm3.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.multihead_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.multihead_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.multihead_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.multihead_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.norm3.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.1.norm3.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.multihead_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.multihead_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.multihead_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.multihead_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.norm3.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.2.norm3.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.multihead_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.multihead_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.multihead_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.multihead_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.norm3.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.3.norm3.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.multihead_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.multihead_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.multihead_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.multihead_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.norm3.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.4.norm3.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.self_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.self_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.self_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.self_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.multihead_attn.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.multihead_attn.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.multihead_attn.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.multihead_attn.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.linear1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.linear1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.linear2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.linear2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.norm1.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.norm1.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.norm2.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.norm2.bias is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.norm3.weight is on cuda:0, moving to cuda
# Warning: Parameter decoder.layers.5.norm3.bias is on cuda:0, moving to cuda
# Warning: Parameter output_norm.weight is on cuda:0, moving to cuda
# Warning: Parameter output_norm.bias is on cuda:0, moving to cuda
# Warning: Parameter output_layer.weight is on cuda:0, moving to cuda
# Warning: Parameter output_layer.bias is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.0.weight is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.0.bias is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.1.weight is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.1.bias is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.4.weight is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.4.bias is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.5.weight is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.5.bias is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.8.weight is on cuda:0, moving to cuda
# Warning: Parameter contract_vulnerability_head.8.bias is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.0.weight is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.0.bias is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.1.weight is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.1.bias is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.4.weight is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.4.bias is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.5.weight is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.5.bias is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.8.weight is on cuda:0, moving to cuda
# Warning: Parameter line_vulnerability_head.8.bias is on cuda:0, moving to cuda
# Warning: Parameter ast_attention.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter ast_attention.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter ast_attention.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter ast_attention.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter cross_attention.in_proj_weight is on cuda:0, moving to cuda
# Warning: Parameter cross_attention.in_proj_bias is on cuda:0, moving to cuda
# Warning: Parameter cross_attention.out_proj.weight is on cuda:0, moving to cuda
# Warning: Parameter cross_attention.out_proj.bias is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.0.weight is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.0.bias is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.1.weight is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.1.bias is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.4.weight is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.4.bias is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.5.weight is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.5.bias is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.8.weight is on cuda:0, moving to cuda
# Warning: Parameter feature_fusion.8.bias is on cuda:0, moving to cuda
# 🚀 Smart Contract Vulnerability Detection Model Loaded Successfully!
# ==========================================================================================
#
# 📋 SC-T-GAN: Smart Contract Transformer GAN - Vulnerability Detection Mode
# --------------------------------------------------------------------------------
#
# ============================================================
# VULNERABILITY ANALYSIS REPORT: VulnerableContract
# ============================================================
#
# 📋 CONTRACT-LEVEL VULNERABILITIES:
# ----------------------------------------
# ARTHM        | 🔴 VULNERABLE    | Probability: 0.699
# DOS          | 🔴 VULNERABLE    | Probability: 0.325
# LE           | 🔴 VULNERABLE    | Probability: 0.336
# RENT         | 🔴 VULNERABLE    | Probability: 0.447
# TimeM        | 🔴 VULNERABLE    | Probability: 0.322
# TimeO        | 🔴 VULNERABLE    | Probability: 0.313
# Tx-Origin    | 🟢 SAFE          | Probability: 0.002
# UE           | 🟢 SAFE          | Probability: 0.287
#
# 📄 LINE-LEVEL VULNERABILITIES:
# ----------------------------------------
#
# 📊 SUMMARY:
# ----------------------------------------
# Total vulnerable lines: 0
# Vulnerability types found: ARTHM, DOS, LE, RENT, TimeM, TimeO
#
#
# 🔧 EXAMPLE 2: Synthetic Contract Generation
# ----------------------------------------
#
# Generated Contract 1:
# ------------------------------
#
#
# Generated Contract 2:
# ------------------------------
#
#
#
# 🔍 EXAMPLE 3: Analyzing Generated Contracts
# ----------------------------------------
#
# Analyzing Generated Contract 1...
#
# ============================================================
# VULNERABILITY ANALYSIS REPORT: GeneratedContract_1
# ============================================================
#
# 📋 CONTRACT-LEVEL VULNERABILITIES:
# ----------------------------------------
# ARTHM        | 🔴 VULNERABLE    | Probability: 0.699
# DOS          | 🔴 VULNERABLE    | Probability: 0.325
# LE           | 🔴 VULNERABLE    | Probability: 0.336
# RENT         | 🔴 VULNERABLE    | Probability: 0.447
# TimeM        | 🔴 VULNERABLE    | Probability: 0.322
# TimeO        | 🔴 VULNERABLE    | Probability: 0.313
# Tx-Origin    | 🟢 SAFE          | Probability: 0.002
# UE           | 🟢 SAFE          | Probability: 0.287
#
# 📄 LINE-LEVEL VULNERABILITIES:
# ----------------------------------------
#
# 📊 SUMMARY:
# ----------------------------------------
# Total vulnerable lines: 0
# Vulnerability types found: ARTHM, DOS, LE, RENT, TimeM, TimeO
#
# Analyzing Generated Contract 2...
#
# ============================================================
# VULNERABILITY ANALYSIS REPORT: GeneratedContract_2
# ============================================================
#
# 📋 CONTRACT-LEVEL VULNERABILITIES:
# ----------------------------------------
# ARTHM        | 🔴 VULNERABLE    | Probability: 0.699
# DOS          | 🔴 VULNERABLE    | Probability: 0.325
# LE           | 🔴 VULNERABLE    | Probability: 0.336
# RENT         | 🔴 VULNERABLE    | Probability: 0.447
# TimeM        | 🔴 VULNERABLE    | Probability: 0.322
# TimeO        | 🔴 VULNERABLE    | Probability: 0.313
# Tx-Origin    | 🟢 SAFE          | Probability: 0.002
# UE           | 🟢 SAFE          | Probability: 0.287
#
# 📄 LINE-LEVEL VULNERABILITIES:
# ----------------------------------------
#
# 📊 SUMMARY:
# ----------------------------------------
# Total vulnerable lines: 0
# Vulnerability types found: ARTHM, DOS, LE, RENT, TimeM, TimeO
#
#
# 📊 EXAMPLE 4: Batch Analysis
# ----------------------------------------
# Analyzing contract 1/3...
# Analyzing contract 2/3...
# Analyzing contract 3/3...
#
# Batch Analysis Result 1:
#   Total vulnerable lines: 0
#   Vulnerability types: ARTHM, DOS, LE, RENT, TimeM, TimeO
#
# Batch Analysis Result 2:
#   Total vulnerable lines: 0
#   Vulnerability types: ARTHM, DOS, LE, RENT, TimeM, TimeO
#
# Batch Analysis Result 3:
#   Total vulnerable lines: 0
#   Vulnerability types: ARTHM, DOS, LE, RENT, TimeM, TimeO
#
# ✅ All examples completed successfully!
